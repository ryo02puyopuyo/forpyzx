# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import openpyxl
import japanize_matplotlib # 追加

# %%
csv_file_path = "/home/rest/forpyzx/output/0422_teleport_basic_10000.csv"

df = pd.read_csv(csv_file_path)
plot_style = "o"

# %%
# 全ゲート数
qubits = [4,8,12,16]
gates = 10000
p_t_lists = [i * 0.04 for i in range(0, 11)]
optimize_name = ["original","basic","clifford","phase","full","phase_no_pre"]

#fig,axes = plt.subplots(7,11)
fig, ax = plt.subplots(len(qubits),figsize=(10, 25),constrained_layout=True)

#p_tを変化させた時のゲート数
for qubit in range(len(qubits)):
        ax[qubit].set_title(f"{qubits[qubit]}量子ビット",fontsize=40)
        ax[qubit].set_xlabel("p_t",fontsize=30)
        ax[qubit].set_ylabel("全量子ゲート数",fontsize=30)
        ax[qubit].set_xlim(min(p_t_lists),max(p_t_lists)+0.02)
        ax[qubit].set_xticks(p_t_lists)
        ax[qubit].set_ylim(0,gates*1.1)
        ax[qubit].grid(True)
        ax[qubit].tick_params(labelsize=22)

        for optimize in optimize_name:
            data = df[(df["optimize_name"] == optimize) &  (df["qubit"] == qubits[qubit]) ]

            mean_data = (data.groupby("p_t", as_index=False)["all_gates"].mean())
            #print(mean_data[mean_data["p_t"] == 0.04] , optimize ,qubits[qubit])
            if optimize == "phase" or optimize == "phase_no_pre":
                plot_style = "x"
            else:
                plot_style = "o"

            ax[qubit].plot(mean_data["p_t"],mean_data["all_gates"],plot_style,linestyle='-',markersize=7,label=optimize)
            ax[qubit].legend(fontsize=22)

plt.savefig("/home/rest/forpyzx/gazou/0423/all_gates.pdf", format="pdf")
plt.show()

# %%
# 1ゲート数
qubits = [4,8,12,16]
gates = 10000
p_t_lists = [i * 0.04 for i in range(0, 11)]
optimize_name = ["original","basic","clifford","phase","full","phase_no_pre"]

#fig,axes = plt.subplots(7,11)
fig, ax = plt.subplots(len(qubits),figsize=(10, 25),constrained_layout=True)

#p_tを変化させた時のゲート数
for qubit in range(len(qubits)):
        ax[qubit].set_title(f"{qubits[qubit]}量子ビット",fontsize=40)
        ax[qubit].set_xlabel("p_t",fontsize=30)
        ax[qubit].set_ylabel("1-量子ゲート数",fontsize=30)
        ax[qubit].set_xlim(min(p_t_lists),max(p_t_lists)+0.02)
        ax[qubit].set_xticks(p_t_lists)
        ax[qubit].set_ylim(0,gates*1.1)
        ax[qubit].grid(True)
        ax[qubit].tick_params(labelsize=22)

        for optimize in optimize_name:
            data = df[(df["optimize_name"] == optimize) &  (df["qubit"] == qubits[qubit]) ]

            mean_data = (data.groupby("p_t", as_index=False)["one-qubit_gates"].mean())
            #print(mean_data[mean_data["p_t"] == 0.04] , optimize ,qubits[qubit])

            if optimize == "phase" or optimize == "phase_no_pre":
                plot_style = "x"
            else:
                plot_style = "o"
                  
            ax[qubit].plot(mean_data["p_t"],mean_data["one-qubit_gates"],plot_style,linestyle='-',markersize=7,label=optimize)
            ax[qubit].legend(fontsize=22)

plt.savefig("/home/rest/forpyzx/gazou/0423/one_gates.pdf", format="pdf")
plt.show()

# %%
# 全ゲート数
qubits = [4,8,12,16]
gates = 10000
p_t_lists = [i * 0.04 for i in range(0, 11)]
optimize_name = ["original","basic","clifford","phase","full","phase_no_pre"]

#fig,axes = plt.subplots(7,11)
fig, ax = plt.subplots(len(qubits),figsize=(10, 25),constrained_layout=True)

#p_tを変化させた時のゲート数
for qubit in range(len(qubits)):
        ax[qubit].set_title(f"{qubits[qubit]}量子ビット",fontsize=40)
        ax[qubit].set_xlabel("p_t",fontsize=30)
        ax[qubit].set_ylabel("2-量子ゲート数",fontsize=30)
        ax[qubit].set_xlim(min(p_t_lists),max(p_t_lists)+0.02)
        ax[qubit].set_xticks(p_t_lists)
        ax[qubit].set_ylim(0,8000)
        ax[qubit].grid(True)
        ax[qubit].tick_params(labelsize=22)

        for optimize in optimize_name:
            data = df[(df["optimize_name"] == optimize) &  (df["qubit"] == qubits[qubit]) ]

            mean_data = (data.groupby("p_t", as_index=False)["two-qubit gates"].mean())
            print(mean_data[mean_data["p_t"] == 0.04] , optimize ,qubits[qubit])

            if optimize == "phase" or optimize == "phase_no_pre":
                plot_style = "x"
            else:
                plot_style = "o"

            ax[qubit].plot(mean_data["p_t"],mean_data["two-qubit gates"],plot_style,linestyle='-',markersize=7,label=optimize)
            ax[qubit].legend(fontsize=22)

plt.savefig("/home/rest/forpyzx/gazou/0423/two_gates.pdf", format="pdf")
plt.show()
# Out:
#     p_t  two-qubit gates
# 1  0.04           3162.2 original 4
#     p_t  two-qubit gates
# 1  0.04           1986.4 basic 4
#     p_t  two-qubit gates
# 1  0.04            636.6 clifford 4
#     p_t  two-qubit gates
# 1  0.04           1976.8 phase 4
#     p_t  two-qubit gates
# 1  0.04            580.2 full 4
#     p_t  two-qubit gates
# 1  0.04           1980.4 phase_no_pre 4
#     p_t  two-qubit gates
# 1  0.04           3141.0 original 8
#     p_t  two-qubit gates
# 1  0.04           2655.0 basic 8
#     p_t  two-qubit gates
# 1  0.04           1514.0 clifford 8
#     p_t  two-qubit gates
# 1  0.04           2653.8 phase 8
#     p_t  two-qubit gates
# 1  0.04           1464.6 full 8
#     p_t  two-qubit gates
# 1  0.04           2655.0 phase_no_pre 8
#     p_t  two-qubit gates
# 1  0.04           3183.4 original 12
#     p_t  two-qubit gates
# 1  0.04           2887.2 basic 12
#     p_t  two-qubit gates
# 1  0.04           2320.2 clifford 12
#     p_t  two-qubit gates
# 1  0.04           2882.2 phase 12
#     p_t  two-qubit gates
# 1  0.04           2297.8 full 12
#     p_t  two-qubit gates
# 1  0.04           2887.2 phase_no_pre 12
#     p_t  two-qubit gates
# 1  0.04           3134.0 original 16
#     p_t  two-qubit gates
# 1  0.04           2934.4 basic 16
#     p_t  two-qubit gates
# 1  0.04           3358.0 clifford 16
#     p_t  two-qubit gates
# 1  0.04           2932.8 phase 16
#     p_t  two-qubit gates
# 1  0.04           3352.8 full 16
#     p_t  two-qubit gates
# 1  0.04           2934.0 phase_no_pre 16

# %%
# Tゲート数
qubits = [4,8,12,16]
gates = 10000
p_t_lists = [i * 0.04 for i in range(0, 11)]
optimize_name = ["original","basic","clifford","phase","full","phase_no_pre"]

#fig,axes = plt.subplots(7,11)
fig, ax = plt.subplots(len(qubits),figsize=(10, 25),constrained_layout=True)

#p_tを変化させた時のゲート数
for qubit in range(len(qubits)):
        ax[qubit].set_title(f"{qubits[qubit]}量子ビット",fontsize=40)
        ax[qubit].set_xlabel("p_t",fontsize=30)
        ax[qubit].set_ylabel("Tゲート数",fontsize=30)
        ax[qubit].set_xlim(min(p_t_lists),max(p_t_lists)+0.02)
        ax[qubit].set_xticks(p_t_lists)
        ax[qubit].set_ylim(1000,1250)
        ax[qubit].grid(True)
        ax[qubit].tick_params(labelsize=22)

        for optimize in optimize_name:
            data = df[(df["optimize_name"] == optimize) &  (df["qubit"] == qubits[qubit]) ]

            mean_data = (data.groupby("p_t", as_index=False)["t"].mean())
            print(mean_data[mean_data["p_t"] == 0.04] , optimize ,qubits[qubit])

            if optimize == "phase" or optimize == "phase_no_pre":
                plot_style = "x"
            else:
                plot_style = "o"

            ax[qubit].plot(mean_data["p_t"],mean_data["t"],plot_style,linestyle='-',markersize=7,label=optimize)
            ax[qubit].legend(fontsize=22)

plt.savefig("/home/rest/forpyzx/gazou/0423/t_gates_kakudai.pdf", format="pdf")
plt.show()
# Out:
#     p_t      t
# 1  0.04  395.4 original 4
#     p_t      t
# 1  0.04  340.6 basic 4
#     p_t      t
# 1  0.04  333.8 clifford 4
#     p_t      t
# 1  0.04  333.4 phase 4
#     p_t      t
# 1  0.04  333.4 full 4
#     p_t      t
# 1  0.04  333.4 phase_no_pre 4
#     p_t      t
# 1  0.04  405.0 original 8
#     p_t      t
# 1  0.04  354.6 basic 8
#     p_t      t
# 1  0.04  353.8 clifford 8
#     p_t      t
# 1  0.04  353.8 phase 8
#     p_t      t
# 1  0.04  353.8 full 8
#     p_t      t
# 1  0.04  353.8 phase_no_pre 8
#     p_t      t
# 1  0.04  391.4 original 12
#     p_t      t
# 1  0.04  339.8 basic 12
#     p_t      t
# 1  0.04  339.4 clifford 12
#     p_t      t
# 1  0.04  339.4 phase 12
#     p_t      t
# 1  0.04  339.4 full 12
#     p_t      t
# 1  0.04  339.4 phase_no_pre 12
#     p_t      t
# 1  0.04  410.2 original 16
#     p_t      t
# 1  0.04  357.0 basic 16
#     p_t      t
# 1  0.04  356.6 clifford 16
#     p_t      t
# 1  0.04  356.6 phase 16
#     p_t      t
# 1  0.04  356.6 full 16
#     p_t      t
# 1  0.04  356.6 phase_no_pre 16
