# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import openpyxl
import japanize_matplotlib # 追加

# %%
csv_file_path = "/home/rest/forpyzx/kekka0120/0120ori_basic_cliffrod_10000.csv"

df = pd.read_csv(csv_file_path)
plot_style = "o"

# %%
# 全ゲート数
qubits = [4,8,12,16]
gates = 10000
p_t_lists = [i * 0.04 for i in range(0, 11)]
optimize_name = ["Original","Basic","CliffordSimp"]

#fig,axes = plt.subplots(7,11)
fig, ax = plt.subplots(len(qubits),figsize=(10, 25),constrained_layout=True)

#p_tを変化させた時のゲート数
for qubit in range(len(qubits)):
        ax[qubit].set_title(f"{qubits[qubit]}量子ビット",fontsize=40)
        ax[qubit].set_xlabel("p_t",fontsize=30)
        ax[qubit].set_ylabel("全量子ゲート数",fontsize=30)
        ax[qubit].set_xlim(min(p_t_lists),max(p_t_lists)+0.02)
        ax[qubit].set_xticks(p_t_lists)
        ax[qubit].set_ylim(0,gates*1.1)
        ax[qubit].grid(True)
        ax[qubit].tick_params(labelsize=22)

        for optimize in optimize_name:
            data = df[(df["optimize_name"] == optimize) &  (df["qubit"] == qubits[qubit]) ]

            mean_data = (data.groupby("p_t", as_index=False)["all_gates"].mean())
            print(mean_data[mean_data["p_t"] == 0.04] , optimize ,qubits[qubit])

            ax[qubit].plot(mean_data["p_t"],mean_data["all_gates"],plot_style,linestyle='-',markersize=7,label=optimize)
            ax[qubit].legend(fontsize=22)

plt.savefig("/home/rest/forpyzx/soturon_gazou/all_gates.pdf", format="pdf")
plt.show()
# Out:
#     p_t  all_gates
# 1  0.04    10000.0 Original 4
#     p_t  all_gates
# 1  0.04     4439.2 Basic 4
#     p_t  all_gates
# 1  0.04     1349.8 CliffordSimp 4
#     p_t  all_gates
# 1  0.04    10000.0 Original 8
#     p_t  all_gates
# 1  0.04     5294.8 Basic 8
#     p_t  all_gates
# 1  0.04     2356.2 CliffordSimp 8
#     p_t  all_gates
# 1  0.04    10000.0 Original 12
#     p_t  all_gates
# 1  0.04     5538.6 Basic 12
#     p_t  all_gates
# 1  0.04     3200.0 CliffordSimp 12
#     p_t  all_gates
# 1  0.04    10000.0 Original 16
#     p_t  all_gates
# 1  0.04     5609.2 Basic 16
#     p_t  all_gates
# 1  0.04     4335.6 CliffordSimp 16

# %%
# 1qubit ゲート数
qubits = [4,8,12,16]
gates = 10000
p_t_lists = [i * 0.04 for i in range(0, 11)]
optimize_name = ["Original","Basic","CliffordSimp"]

#fig,axes = plt.subplots(7,11)
fig, ax = plt.subplots(len(qubits),figsize=(10, 25),constrained_layout=True)

#p_tを変化させた時のゲート数
for qubit in range(len(qubits)):
        ax[qubit].set_title(f"{qubits[qubit]}量子ビット",fontsize=40)
        ax[qubit].set_xlabel("p_t",fontsize=30)
        ax[qubit].set_ylabel("一量子ゲート数",fontsize=30)
        ax[qubit].set_xlim(min(p_t_lists),max(p_t_lists)+0.02)
        ax[qubit].set_xticks(p_t_lists)
        ax[qubit].set_ylim(0,gates*1.1)
        ax[qubit].grid(True)
        ax[qubit].tick_params(labelsize=22)

        for optimize in optimize_name:
            data = df[(df["optimize_name"] == optimize) &  (df["qubit"] == qubits[qubit]) ]

            mean_data = (data.groupby("p_t", as_index=False)["one-qubit_gates"].mean())
            print(mean_data[mean_data["p_t"] == 0.04] , optimize ,qubits[qubit])

            ax[qubit].plot(mean_data["p_t"],mean_data["one-qubit_gates"],plot_style,linestyle='-',markersize=7,label=optimize)
            ax[qubit].legend(fontsize=22)
plt.savefig("/home/rest/forpyzx/soturon_gazou/one-qubit_gates.pdf", format="pdf")
plt.show()
# Out:
#     p_t  one-qubit_gates
# 1  0.04           6837.8 Original 4
#     p_t  one-qubit_gates
# 1  0.04           2452.8 Basic 4
#     p_t  one-qubit_gates
# 1  0.04            713.2 CliffordSimp 4
#     p_t  one-qubit_gates
# 1  0.04           6859.0 Original 8
#     p_t  one-qubit_gates
# 1  0.04           2639.8 Basic 8
#     p_t  one-qubit_gates
# 1  0.04            842.2 CliffordSimp 8
#     p_t  one-qubit_gates
# 1  0.04           6816.6 Original 12
#     p_t  one-qubit_gates
# 1  0.04           2651.4 Basic 12
#     p_t  one-qubit_gates
# 1  0.04            879.8 CliffordSimp 12
#     p_t  one-qubit_gates
# 1  0.04           6866.0 Original 16
#     p_t  one-qubit_gates
# 1  0.04           2674.8 Basic 16
#     p_t  one-qubit_gates
# 1  0.04            977.6 CliffordSimp 16

# %%
# 1qubit ゲート数
qubits = [4,8,12,16]
gates = 10000
p_t_lists = [i * 0.04 for i in range(0, 11)]
optimize_name = ["Original","Basic","CliffordSimp"]

#fig,axes = plt.subplots(7,11)
fig, ax = plt.subplots(len(qubits),figsize=(10, 25),constrained_layout=True)

#p_tを変化させた時のゲート数
for qubit in range(len(qubits)):
        ax[qubit].set_title(f"{qubits[qubit]}量子ビット",fontsize=40)
        ax[qubit].set_xlabel("p_t",fontsize=30)
        ax[qubit].set_ylabel("二量子ゲート数",fontsize=30)
        ax[qubit].set_xlim(min(p_t_lists),max(p_t_lists)+0.02)
        ax[qubit].set_xticks(p_t_lists)
        ax[qubit].set_ylim(0,gates*1.1)
        ax[qubit].grid(True)
        ax[qubit].tick_params(labelsize=22)

        for optimize in optimize_name:
            data = df[(df["optimize_name"] == optimize) &  (df["qubit"] == qubits[qubit]) ]

            mean_data = (data.groupby("p_t", as_index=False)["two-qubit gates"].mean())
            print(mean_data[mean_data["p_t"] == 0.04] , optimize ,qubits[qubit])

            ax[qubit].plot(mean_data["p_t"],mean_data["two-qubit gates"],plot_style,linestyle='-',markersize=7,label=optimize)
            ax[qubit].legend(fontsize=22)
plt.savefig("/home/rest/forpyzx/soturon_gazou/two-qubit_gates.pdf", format="pdf")

plt.show()
# Out:
#     p_t  two-qubit gates
# 1  0.04           3162.2 Original 4
#     p_t  two-qubit gates
# 1  0.04           1986.4 Basic 4
#     p_t  two-qubit gates
# 1  0.04            636.6 CliffordSimp 4
#     p_t  two-qubit gates
# 1  0.04           3141.0 Original 8
#     p_t  two-qubit gates
# 1  0.04           2655.0 Basic 8
#     p_t  two-qubit gates
# 1  0.04           1514.0 CliffordSimp 8
#     p_t  two-qubit gates
# 1  0.04           3183.4 Original 12
#     p_t  two-qubit gates
# 1  0.04           2887.2 Basic 12
#     p_t  two-qubit gates
# 1  0.04           2320.2 CliffordSimp 12
#     p_t  two-qubit gates
# 1  0.04           3134.0 Original 16
#     p_t  two-qubit gates
# 1  0.04           2934.4 Basic 16
#     p_t  two-qubit gates
# 1  0.04           3358.0 CliffordSimp 16

# %%
# 1qubit ゲート数
qubits = [4,8,12,16]
gates = 10000
p_t_lists = [i * 0.04 for i in range(0, 11)]
#p_t_lists = [i * 0.08 for i in range(0, 6)]
p_t_lists= [0.00,0.12,0.24,0.40]
optimize_name = ["Original","Basic","CliffordSimp"]

#fig,axes = plt.subplots(7,11)
fig, ax = plt.subplots(len(p_t_lists),figsize=(10, 25),constrained_layout=True)

#p_tを変化させた時のゲート数
for p_t in range(len(p_t_lists)):
        ax[p_t].set_title(f"Tゲートの割合={p_t_lists[p_t]}",fontsize=20)
        ax[p_t].set_xlabel("量子ビット数",fontsize=20)
        ax[p_t].set_ylabel("全ゲート数",fontsize=20)
        ax[p_t].set_xlim(qubits[0],qubits[-1])
        ax[p_t].set_xticks(qubits)
        ax[p_t].set_ylim(0,11000)
        ax[p_t].grid(True)
        ax[p_t].tick_params(labelsize=18)

        for optimize in optimize_name:
            data = df[(df["optimize_name"] == optimize) &  (df["p_t"] == p_t_lists[p_t]) ]

            mean_data = (data.groupby("qubit", as_index=False)["all_gates"].mean())
            print(mean_data)
            #print(mean_data[mean_data["p_t"] == 0.04] , optimize ,qubits[qubit])

            ax[p_t].plot(mean_data["qubit"],mean_data["all_gates"],plot_style,linestyle='-',markersize=7,label=optimize)
            ax[p_t].legend(fontsize=15)
#plt.savefig("/home/rest/forpyzx/soturon_gazou/two-qubit_gates.pdf", format="pdf")

plt.show()
# Out:
#    qubit  all_gates
# 0      4    10000.0
# 1      8    10000.0
# 2     12    10000.0
# 3     16    10000.0
#    qubit  all_gates
# 0      4     4223.6
# 1      8     5150.8
# 2     12     5467.0
# 3     16     5513.2
#    qubit  all_gates
# 0      4       19.0
# 1      8       67.6
# 2     12      140.2
# 3     16      236.6
#    qubit  all_gates
# 0      4    10000.0
# 1      8    10000.0
# 2     12    10000.0
# 3     16    10000.0
#    qubit  all_gates
# 0      4     4711.2
# 1      8     5371.8
# 2     12     5614.6
# 3     16     5666.4
#    qubit  all_gates
# 0      4     2923.0
# 1      8     4728.8
# 2     12     6530.6
# 3     16     8125.4
#    qubit  all_gates
# 0      4    10000.0
# 1      8    10000.0
# 2     12    10000.0
# 3     16    10000.0
#    qubit  all_gates
# 0      4     4665.0
# 1      8     5207.2
# 2     12     5346.2
# 3     16     5421.6
#    qubit  all_gates
# 0      4     3768.6
# 1      8     5777.0
# 2     12     7399.0
# 3     16     8978.8
#    qubit  all_gates
# 0      4    10000.0
# 1      8    10000.0
# 2     12    10000.0
# 3     16    10000.0
#    qubit  all_gates
# 0      4     4179.0
# 1      8     4613.2
# 2     12     4730.8
# 3     16     4778.4
#    qubit  all_gates
# 0      4     3778.2
# 1      8     5498.2
# 2     12     6637.2
# 3     16     7488.8

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 量子ビット数とゲート数の設定
qubits = [4, 8, 12, 16]
p_t_lists = [i * 0.08 for i in range(6)]  # 0.00 から 0.40 まで 0.08 刻み
optimize_name = ["Original", "Basic", "CliffordSimp"]

# データフレーム（df）が既に存在すると仮定
# 2列表示に変更
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 15), constrained_layout=True)

# p_t を変化させた時のゲート数
for idx, p_t in enumerate(p_t_lists):
    row, col = divmod(idx, 3)  # 2行3列に配置
    ax = axes[row, col]
    
    ax.set_title(f"p_t={p_t}", fontsize=40)
    ax.set_xlabel("量子ビット数", fontsize=30)
    ax.set_ylabel("全量子ゲート数", fontsize=30)
    ax.set_xlim(qubits[0], qubits[-1])
    ax.set_xticks(qubits)
    ax.set_ylim(0, 11000)
    ax.grid(True)
    ax.tick_params(labelsize=25)

    for optimize in optimize_name:
        data = df[(df["optimize_name"] == optimize) & (df["p_t"] == p_t)]
        mean_data = data.groupby("qubit", as_index=False)["all_gates"].mean()
        
        ax.plot(
            mean_data["qubit"], mean_data["all_gates"], 
            linestyle='-', marker='o', markersize=7, label=optimize  # マーカーを'o'に設定
        )
        ax.legend(fontsize=22)

# 空のプロットを削除（p_t_lists の長さが 6 で、2×3 の枠を超えた場合）
if len(p_t_lists) < 6:
    for i in range(len(p_t_lists), 6):
        row, col = divmod(i, 3)
        fig.delaxes(axes[row, col])

plt.show()

# %%
#スライド用
# 全ゲート数
qubits = [4,16]
gates = 10000
p_t_lists = [i * 0.04 for i in range(0, 11)]
optimize_name = ["Original","Basic","CliffordSimp"]

#fig,axes = plt.subplots(7,11)
fig, ax = plt.subplots(len(qubits),figsize=(13, 15),constrained_layout=True)

#p_tを変化させた時のゲート数
for qubit in range(len(qubits)):
        ax[qubit].set_title(f"{qubits[qubit]}量子ビット",fontsize=30)
        ax[qubit].set_xlabel("Tゲートの割合",fontsize=30)
        ax[qubit].set_ylabel("全ゲート数",fontsize=30)
        ax[qubit].set_xlim(min(p_t_lists),max(p_t_lists)+0.02)
        ax[qubit].set_xticks(p_t_lists)
        ax[qubit].set_ylim(0,gates*1.1)
        ax[qubit].grid(True)
        ax[qubit].tick_params(labelsize=25)

        for optimize in optimize_name:
            data = df[(df["optimize_name"] == optimize) &  (df["qubit"] == qubits[qubit]) ]

            mean_data = (data.groupby("p_t", as_index=False)["all_gates"].mean())
            print(mean_data[mean_data["p_t"] == 0.04] , optimize ,qubits[qubit])
            if(optimize == "Original"):
                label = "入力量子回路"
            elif (optimize == "Basic"):
                label = "直接最適化"
            else:
                label = "ZX最適化"
            ax[qubit].plot(mean_data["p_t"],mean_data["all_gates"],plot_style,linestyle='-',markersize=7,label=label)
            ax[qubit].legend(fontsize=25)

plt.savefig("/home/rest/forpyzx/soturon_gazou/all_gates.pdf", format="pdf")
plt.show()
# Out:
#     p_t  all_gates
# 1  0.04    10000.0 Original 4
#     p_t  all_gates
# 1  0.04     4439.2 Basic 4
#     p_t  all_gates
# 1  0.04     1349.8 CliffordSimp 4
#     p_t  all_gates
# 1  0.04    10000.0 Original 16
#     p_t  all_gates
# 1  0.04     5609.2 Basic 16
#     p_t  all_gates
# 1  0.04     4335.6 CliffordSimp 16

# %%
# 1qubit ゲート数
qubits = [4,16]
gates = 10000
p_t_lists = [i * 0.04 for i in range(0, 11)]
optimize_name = ["Original","Basic","CliffordSimp"]

#fig,axes = plt.subplots(7,11)
fig, ax = plt.subplots(len(qubits),figsize=(13, 15),constrained_layout=True)

#p_tを変化させた時のゲート数
for qubit in range(len(qubits)):
        ax[qubit].set_title(f"{qubits[qubit]}量子ビット",fontsize=30)
        ax[qubit].set_xlabel("Tゲートの割合",fontsize=30)
        ax[qubit].set_ylabel("二量子ゲート数",fontsize=30)
        ax[qubit].set_xlim(min(p_t_lists),max(p_t_lists)+0.02)
        ax[qubit].set_xticks(p_t_lists)
        ax[qubit].set_ylim(0,gates)
        ax[qubit].grid(True)
        ax[qubit].tick_params(labelsize=25)

        for optimize in optimize_name:
            data = df[(df["optimize_name"] == optimize) &  (df["qubit"] == qubits[qubit]) ]

            mean_data = (data.groupby("p_t", as_index=False)["two-qubit gates"].mean())
            print(mean_data[mean_data["p_t"] == 0.04] , optimize ,qubits[qubit])
            print(optimize)
            if(optimize == "Original"):
                label = "入力量子回路"
            elif (optimize == "Basic"):
                label = "直接最適化"
            else:
                label = "ZX最適化"

            ax[qubit].plot(mean_data["p_t"],mean_data["two-qubit gates"],plot_style,linestyle='-',markersize=7,label=label)
            ax[qubit].legend(fontsize=25)
plt.savefig("/home/rest/forpyzx/soturon_gazou/two-qubit_gates.pdf", format="pdf")

plt.show()
# Out:
#     p_t  two-qubit gates
# 1  0.04           3162.2 Original 4
# Original
#     p_t  two-qubit gates
# 1  0.04           1986.4 Basic 4
# Basic
#     p_t  two-qubit gates
# 1  0.04            636.6 CliffordSimp 4
# CliffordSimp
#     p_t  two-qubit gates
# 1  0.04           3134.0 Original 16
# Original
#     p_t  two-qubit gates
# 1  0.04           2934.4 Basic 16
# Basic
#     p_t  two-qubit gates
# 1  0.04           3358.0 CliffordSimp 16
# CliffordSimp
