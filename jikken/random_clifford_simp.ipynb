# %%
import pyzx as zx
import random
from qiskit import QuantumCircuit
from qiskit.circuit import QuantumCircuit, ParameterVector
import csv
import time

# %%
def generate_H_S_CNOT_T_circuit(qubits, gates, p_t=0, seed=1000):
    random.seed(seed)  
    p_s = 0.333 * (1.0 - p_t)  
    p_had = 0.333 * (1.0 - p_t)  
    p_cnot = 0.333 * (1.0 - p_t)  

    c = zx.Circuit(qubits) 
    for _ in range(gates):
        r = random.random() 
        if r < p_had:
            c.add_gate("HAD", random.randrange(qubits))
        elif r < p_had + p_s:
            c.add_gate("S", random.randrange(qubits))
        elif r < p_had + p_s + p_t:
            c.add_gate("T", random.randrange(qubits))
        else:
            tgt = random.randrange(qubits)
            while True:
                ctrl = random.randrange(qubits)
                if ctrl != tgt:
                    break
            c.add_gate("CNOT", tgt, ctrl)
    return c

# %%
# seed固定
seed = 1000
random.seed(seed)

# パラメータ設定
#qubits_list = [4, 8, 12, 16]
qubits_list = [16]
p_t_lists = [i * 0.04 for i in range(0, 11)]
gate_num_lists = [100, 500, 1000, 2000, 5000, 10000, 50000]

# CSV書き込みの準備
output_file = "../kekka/20241203random_clifford_simp_qubits16tuika.csv"
fieldnames = [
    "optimize_name","data_name","gates","depth","t","H","otherRZ","CNOT","CZ","time"
]
start_all = time.time()
with open(output_file, "w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()

    for qubit in qubits_list:
        for gate_num in gate_num_lists:
            for p_t in p_t_lists:
                try:
                    start = time.time()
                    # 回路作成
                    c = generate_H_S_CNOT_T_circuit(qubits = qubit,gates= gate_num,p_t = p_t,seed = seed)
                    c = zx.optimize.basic_optimization(c)
                    g = c.to_graph()
                    zx.simplify.jisaku_random_clifford_simp(g)

                    #抽出
                    c = zx.extract.streaming_extract(g)

                    end = time.time()

                    #qiskit変換とカウント
                    circuit_qiskit = QuantumCircuit.from_qasm_str(c.to_basic_gates().to_qasm())
                    depth = circuit_qiskit.depth()
                    zx_dict = c.to_basic_gates().stats_dict()
                    qiskit_dict = circuit_qiskit.count_ops()

                    optimize_name = "clifford_simp"
                    dataname = "q" + str(qubit) + "_gates" + str(gate_num) + "_pt" +str(p_t)+ "_seeds" + str(seed)
                    gates_aft = zx_dict["gates"]


                    # 結果をCSVに書き込む
                    writer.writerow({
                        "optimize_name": optimize_name,
                        "data_name": dataname,
                        "gates": gates_aft,
                        "depth": depth,
                        "t": zx_dict["tcount"],
                        "H": qiskit_dict.get("h", 0),
                        "otherRZ": gates_aft - qiskit_dict.get("h", 0) - qiskit_dict.get("cx", 0) - qiskit_dict.get("cz", 0) - zx_dict["tcount"],
                        "CNOT": qiskit_dict.get("cx", 0),
                        "CZ": qiskit_dict.get("cz", 0),
                        "time": end - start
                    })

                    print(f"done. Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t},seed={seed},time={end-start}")

                except Exception as e:
                    print(f"Error for Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t}: {e}")

end_all = time.time()
print(f"Total time: {end_all - start_all}")
# Out:
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.0,seed=1000,time=0.051233530044555664
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.04,seed=1000,time=0.015382528305053711
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.08,seed=1000,time=0.013346195220947266
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.12,seed=1000,time=0.009942054748535156
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.16,seed=1000,time=0.01085805892944336
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.2,seed=1000,time=0.012070417404174805
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.24,seed=1000,time=0.01660943031311035
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.28,seed=1000,time=0.011426210403442383
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.32,seed=1000,time=0.01083993911743164
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.36,seed=1000,time=0.008740663528442383
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.4,seed=1000,time=0.007613658905029297
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.0,seed=1000,time=0.12441539764404297
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.04,seed=1000,time=0.5061509609222412
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.08,seed=1000,time=0.14886069297790527
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.12,seed=1000,time=0.1392066478729248
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.16,seed=1000,time=0.1310269832611084
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.2,seed=1000,time=0.11278724670410156
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.24,seed=1000,time=0.10363292694091797
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.28,seed=1000,time=0.08506941795349121
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.32,seed=1000,time=0.10962939262390137
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.36,seed=1000,time=0.0671844482421875
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.4,seed=1000,time=0.06970047950744629
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.0,seed=1000,time=0.3491530418395996
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.04,seed=1000,time=0.8463907241821289
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.08,seed=1000,time=0.6033313274383545
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.12,seed=1000,time=0.3937263488769531
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.16,seed=1000,time=0.36783289909362793
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.2,seed=1000,time=0.27330756187438965
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.24,seed=1000,time=0.2102501392364502
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.28,seed=1000,time=0.19706463813781738
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.32,seed=1000,time=0.24211621284484863
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.36,seed=1000,time=0.13030385971069336
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.4,seed=1000,time=0.1428065299987793
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.0,seed=1000,time=1.017212152481079
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.04,seed=1000,time=2.3284192085266113
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.08,seed=1000,time=1.4453630447387695
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.12,seed=1000,time=1.4164636135101318
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.16,seed=1000,time=0.52716064453125
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.2,seed=1000,time=0.5999758243560791
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.24,seed=1000,time=0.5359973907470703
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.28,seed=1000,time=0.45828986167907715
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.32,seed=1000,time=0.5229907035827637
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.36,seed=1000,time=0.3667149543762207
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.4,seed=1000,time=0.33655595779418945
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.0,seed=1000,time=5.0579588413238525
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.04,seed=1000,time=12.964170217514038
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.08,seed=1000,time=10.275541305541992
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.12,seed=1000,time=7.645358324050903
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.16,seed=1000,time=3.714226484298706
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.2,seed=1000,time=3.085592746734619
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.24,seed=1000,time=2.9029958248138428
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.28,seed=1000,time=3.341200113296509
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.32,seed=1000,time=2.4621927738189697
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.36,seed=1000,time=1.9038186073303223
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.4,seed=1000,time=1.7784910202026367
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.0,seed=1000,time=20.340073108673096
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.04,seed=1000,time=65.91039562225342
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.08,seed=1000,time=39.77146124839783
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.12,seed=1000,time=30.79108691215515
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.16,seed=1000,time=15.326233148574829
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.2,seed=1000,time=11.932684183120728
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.24,seed=1000,time=10.845760107040405
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.28,seed=1000,time=10.493531703948975
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.32,seed=1000,time=10.580262184143066
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.36,seed=1000,time=8.798140287399292
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.4,seed=1000,time=6.587235689163208
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.0,seed=1000,time=504.9213619232178
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 30
#      28 c = zx.optimize.basic_optimization(c)
#      29 g = c.to_graph()
# ---> 30 zx.simplify.jisaku_random_clifford_simp(g)
#      32 #抽出
#      33 c = zx.extract.streaming_extract(g)
#
# File ~/forpyzx/venv/lib/python3.10/site-packages/pyzx/simplify.py:243, in jisaku_random_clifford_simp(g, quiet, stats)
#     239     selected = "end"
#     242 if selected == "pivot":
# --> 243     i3 = jisaku_simp(g, 'random_pivot_simp', jisaku_random_match_pivot, pivot, matchf=None, quiet=quiet, stats=stats)
#     244     prev_i3 = i3
#     245     if i3 > 0:
#
# File ~/forpyzx/venv/lib/python3.10/site-packages/pyzx/simplify.py:126, in jisaku_simp(g, name, match, rewrite, matchf, quiet, stats)
#     124     m = match(g, matchf)
#     125 else:
# --> 126     m = match(g)
#     127 if len(m) > 0:
#     128     i += 1
#
# File ~/forpyzx/venv/lib/python3.10/site-packages/pyzx/rules.py:467, in jisaku_random_match_pivot(g, matchf, num, check_edge_types)
#     465 m = []
#     466 while i < num and len(candidates) > 0:
# --> 467     e = random.sample(list(candidates),1)[0]
#     468     candidates.remove(e)
#     470     if check_edge_types and g.edge_type(e) != EdgeType.HADAMARD: continue
#
# KeyboardInterrupt:
