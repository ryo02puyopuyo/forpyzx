# %%
import pyzx as zx
import random
from qiskit import QuantumCircuit
from qiskit.circuit import QuantumCircuit, ParameterVector
import csv
import time

# %%
def generate_H_S_CNOT_T_circuit(qubits, gates, p_t=0, seed=1000):
    random.seed(seed)  
    p_s = 0.333 * (1.0 - p_t)  
    p_had = 0.333 * (1.0 - p_t)  
    p_cnot = 0.333 * (1.0 - p_t)  

    c = zx.Circuit(qubits) 
    for _ in range(gates):
        r = random.random() 
        if r < p_had:
            c.add_gate("HAD", random.randrange(qubits))
        elif r < p_had + p_s:
            c.add_gate("S", random.randrange(qubits))
        elif r < p_had + p_s + p_t:
            c.add_gate("T", random.randrange(qubits))
        else:
            tgt = random.randrange(qubits)
            while True:
                ctrl = random.randrange(qubits)
                if ctrl != tgt:
                    break
            c.add_gate("CNOT", tgt, ctrl)
    return c

# %%
# seed固定
seed = 1000
random.seed(seed)

# パラメータ設定
qubits_list = [4, 8, 12, 16]
p_t_lists = [i * 0.04 for i in range(0, 11)]
gate_num_lists = [100, 500, 1000, 2000, 5000, 10000, 50000,100000]

# CSV書き込みの準備
output_file = "../kekka/clifford_simp_100000.csv"
fieldnames = [
    "optimize_name","data_name","gates","depth","t","H","otherRZ","CNOT","CZ","time"
]
start_all = time.time()
with open(output_file, "w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()



    for qubit in qubits_list:
        for gate_num in gate_num_lists:
            for p_t in p_t_lists:
                try:
                    start = time.time()
                    # 回路作成
                    c = generate_H_S_CNOT_T_circuit(qubits = qubit,gates= gate_num,p_t = p_t,seed = seed)
                    c = zx.optimize.basic_optimization(c)
                    g = c.to_graph()
                    zx.simplify.clifford_simp(g)


                    #抽出
                    c = zx.extract.streaming_extract(g)

                    end = time.time()

                    #qiskit変換とカウント
                    circuit_qiskit = QuantumCircuit.from_qasm_str(c.to_basic_gates().to_qasm())
                    depth = circuit_qiskit.depth()
                    zx_dict = c.to_basic_gates().stats_dict()
                    qiskit_dict = circuit_qiskit.count_ops()

                    optimize_name = "clifford_simp"
                    dataname = "q" + str(qubit) + "_gates" + str(gate_num) + "_pt" +str(p_t)+ "_seeds" + str(seed)
                    gates_aft = zx_dict["gates"]


                    # 結果をCSVに書き込む
                    writer.writerow({
                        "optimize_name": optimize_name,
                        "data_name": dataname,
                        "gates": gates_aft,
                        "depth": depth,
                        "t": zx_dict["tcount"],
                        "H": qiskit_dict.get("h", 0),
                        "otherRZ": gates_aft - qiskit_dict.get("h", 0) - qiskit_dict.get("cx", 0) - qiskit_dict.get("cz", 0) - zx_dict["tcount"],
                        "CNOT": qiskit_dict.get("cx", 0),
                        "CZ": qiskit_dict.get("cz", 0),
                        "time": end - start
                    })

                    print(f"done. Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t},seed={seed},time={end-start}")

                except Exception as e:
                    print(f"Error for Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t}: {e}")

end_all = time.time()
print(f"Total time: {end_all - start_all}")
# Out:
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.0,seed=1000,time=0.007889270782470703
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.04,seed=1000,time=0.0071201324462890625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.08,seed=1000,time=0.006332874298095703
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.12,seed=1000,time=0.006437778472900391
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.16,seed=1000,time=0.005357265472412109
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.2,seed=1000,time=0.0065500736236572266
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.24,seed=1000,time=0.005692243576049805
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.28,seed=1000,time=0.004479646682739258
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.32,seed=1000,time=0.004430055618286133
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.36,seed=1000,time=0.005818605422973633
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.4,seed=1000,time=0.005203962326049805
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.0,seed=1000,time=0.029132604598999023
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.04,seed=1000,time=0.028211355209350586
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.08,seed=1000,time=0.026482343673706055
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.12,seed=1000,time=0.029058456420898438
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.16,seed=1000,time=0.028043746948242188
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.2,seed=1000,time=0.02492356300354004
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.24,seed=1000,time=0.021476268768310547
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.28,seed=1000,time=0.024623632431030273
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.32,seed=1000,time=0.019427776336669922
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.36,seed=1000,time=0.049182891845703125
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.4,seed=1000,time=0.020616769790649414
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.0,seed=1000,time=0.06158566474914551
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.04,seed=1000,time=0.057102203369140625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.08,seed=1000,time=0.054991960525512695
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.12,seed=1000,time=0.05642986297607422
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.16,seed=1000,time=0.07312488555908203
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.2,seed=1000,time=0.05588674545288086
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.24,seed=1000,time=0.059357643127441406
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.28,seed=1000,time=0.049851417541503906
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.32,seed=1000,time=0.06855583190917969
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.36,seed=1000,time=0.04662156105041504
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.4,seed=1000,time=0.04526972770690918
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.0,seed=1000,time=0.12938880920410156
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.04,seed=1000,time=0.14522457122802734
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.08,seed=1000,time=0.15003681182861328
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.12,seed=1000,time=0.12714552879333496
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.16,seed=1000,time=0.13519740104675293
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.2,seed=1000,time=0.13620781898498535
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.24,seed=1000,time=0.13185739517211914
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.28,seed=1000,time=0.1188056468963623
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.32,seed=1000,time=0.1383507251739502
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.36,seed=1000,time=0.11450433731079102
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.4,seed=1000,time=0.11996126174926758
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.0,seed=1000,time=0.536323070526123
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.04,seed=1000,time=0.44767260551452637
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.08,seed=1000,time=0.4371044635772705
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.12,seed=1000,time=0.5131261348724365
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.16,seed=1000,time=0.4908013343811035
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.2,seed=1000,time=0.42871904373168945
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.24,seed=1000,time=0.4747629165649414
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.28,seed=1000,time=0.48036813735961914
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.32,seed=1000,time=0.45490336418151855
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.36,seed=1000,time=0.4333813190460205
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.4,seed=1000,time=0.44906139373779297
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.0,seed=1000,time=1.3615646362304688
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.04,seed=1000,time=1.2678956985473633
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.08,seed=1000,time=1.426884651184082
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.12,seed=1000,time=1.3781909942626953
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.16,seed=1000,time=1.3850898742675781
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.2,seed=1000,time=1.2428815364837646
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.24,seed=1000,time=1.4577651023864746
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.28,seed=1000,time=1.3824694156646729
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.32,seed=1000,time=1.41072678565979
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.36,seed=1000,time=1.4166691303253174
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.4,seed=1000,time=1.3438282012939453
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.0,seed=1000,time=27.193765878677368
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.04,seed=1000,time=26.13038992881775
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.08,seed=1000,time=24.14883804321289
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.12,seed=1000,time=26.41959834098816
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.16,seed=1000,time=30.5683331489563
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.2,seed=1000,time=28.746088981628418
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.24,seed=1000,time=27.302286624908447
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.28,seed=1000,time=31.59749674797058
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.32,seed=1000,time=30.624087810516357
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.36,seed=1000,time=26.788004398345947
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.4,seed=1000,time=27.545570373535156
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.0,seed=1000,time=118.16221022605896
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.04,seed=1000,time=124.95666265487671
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.08,seed=1000,time=134.4729995727539
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.12,seed=1000,time=139.51168036460876
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.16,seed=1000,time=109.39896750450134
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.2,seed=1000,time=143.17684078216553
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.24,seed=1000,time=127.21867799758911
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.28,seed=1000,time=109.71326231956482
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.32,seed=1000,time=123.21454977989197
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.36,seed=1000,time=113.44644236564636
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.4,seed=1000,time=109.9811840057373
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.0,seed=1000,time=0.011343717575073242
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.04,seed=1000,time=0.008788347244262695
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.08,seed=1000,time=0.008697986602783203
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.12,seed=1000,time=0.008398056030273438
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.16,seed=1000,time=0.008760690689086914
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.2,seed=1000,time=0.008180379867553711
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.24,seed=1000,time=0.007848978042602539
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.28,seed=1000,time=0.007219076156616211
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.32,seed=1000,time=0.006791114807128906
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.36,seed=1000,time=0.006226778030395508
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.4,seed=1000,time=0.005704641342163086
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.0,seed=1000,time=0.03654623031616211
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.04,seed=1000,time=0.038408517837524414
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.08,seed=1000,time=0.039604902267456055
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.12,seed=1000,time=0.0412747859954834
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.16,seed=1000,time=0.03640317916870117
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.2,seed=1000,time=0.03606700897216797
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.24,seed=1000,time=0.03402066230773926
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.28,seed=1000,time=0.03653359413146973
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.32,seed=1000,time=0.028175830841064453
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.36,seed=1000,time=0.027121543884277344
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.4,seed=1000,time=0.0255126953125
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.0,seed=1000,time=0.08244824409484863
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.04,seed=1000,time=0.08413362503051758
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.08,seed=1000,time=0.08586788177490234
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.12,seed=1000,time=0.08145999908447266
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.16,seed=1000,time=0.11563658714294434
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.2,seed=1000,time=0.0798180103302002
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.24,seed=1000,time=0.07422804832458496
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.28,seed=1000,time=0.07588028907775879
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.32,seed=1000,time=0.05797171592712402
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.36,seed=1000,time=0.059606075286865234
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.4,seed=1000,time=0.05533266067504883
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.0,seed=1000,time=0.15607666969299316
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.04,seed=1000,time=0.2144918441772461
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.08,seed=1000,time=0.19571948051452637
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.12,seed=1000,time=0.17898106575012207
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.16,seed=1000,time=0.18540143966674805
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.2,seed=1000,time=0.1530928611755371
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.24,seed=1000,time=0.1885998249053955
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.28,seed=1000,time=0.1431283950805664
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.32,seed=1000,time=0.14907121658325195
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.36,seed=1000,time=0.11907505989074707
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.4,seed=1000,time=0.11494040489196777
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.0,seed=1000,time=0.5520565509796143
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.04,seed=1000,time=0.6815977096557617
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.08,seed=1000,time=0.6963047981262207
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.12,seed=1000,time=0.5877692699432373
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.16,seed=1000,time=0.5255038738250732
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.2,seed=1000,time=0.519801139831543
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.24,seed=1000,time=0.48040223121643066
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.28,seed=1000,time=0.4649837017059326
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.32,seed=1000,time=0.40587472915649414
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.36,seed=1000,time=0.4072103500366211
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.4,seed=1000,time=0.369354248046875
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.0,seed=1000,time=1.4578845500946045
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.04,seed=1000,time=1.6015112400054932
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.08,seed=1000,time=1.467986822128296
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.12,seed=1000,time=1.3561875820159912
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.16,seed=1000,time=1.2170631885528564
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.2,seed=1000,time=1.3230035305023193
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.24,seed=1000,time=1.240135908126831
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.28,seed=1000,time=1.1612236499786377
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.32,seed=1000,time=1.0297772884368896
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.36,seed=1000,time=1.0342304706573486
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.4,seed=1000,time=1.066725730895996
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.0,seed=1000,time=22.853448629379272
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.04,seed=1000,time=19.607548713684082
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.08,seed=1000,time=16.04331874847412
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.12,seed=1000,time=20.319514751434326
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.16,seed=1000,time=21.409626007080078
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.2,seed=1000,time=19.669766664505005
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.24,seed=1000,time=18.34479308128357
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.28,seed=1000,time=15.406766891479492
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.32,seed=1000,time=15.032267808914185
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.36,seed=1000,time=15.637586832046509
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.4,seed=1000,time=15.005484104156494
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.0,seed=1000,time=89.24567437171936
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.04,seed=1000,time=73.23176765441895
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.08,seed=1000,time=76.47489404678345
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.12,seed=1000,time=75.53645324707031
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.16,seed=1000,time=91.5606095790863
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.2,seed=1000,time=74.66097164154053
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.24,seed=1000,time=67.1528091430664
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.28,seed=1000,time=64.04013919830322
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.32,seed=1000,time=64.80970168113708
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.36,seed=1000,time=63.92934823036194
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.4,seed=1000,time=58.50269889831543
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.0,seed=1000,time=0.010022401809692383
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.04,seed=1000,time=0.0064334869384765625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.08,seed=1000,time=0.008854150772094727
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.12,seed=1000,time=0.0065765380859375
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.16,seed=1000,time=0.008375167846679688
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.2,seed=1000,time=0.006993770599365234
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.24,seed=1000,time=0.007402181625366211
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.28,seed=1000,time=0.007113456726074219
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.32,seed=1000,time=0.00575566291809082
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.36,seed=1000,time=0.005062580108642578
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.4,seed=1000,time=0.005224943161010742
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.0,seed=1000,time=0.03870415687561035
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.04,seed=1000,time=0.07151269912719727
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.08,seed=1000,time=0.06381344795227051
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.12,seed=1000,time=0.06365513801574707
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.16,seed=1000,time=0.0534212589263916
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.2,seed=1000,time=0.04509925842285156
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.24,seed=1000,time=0.042704105377197266
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.28,seed=1000,time=0.04137110710144043
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.32,seed=1000,time=0.03290724754333496
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.36,seed=1000,time=0.037473440170288086
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.4,seed=1000,time=0.031503915786743164
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.0,seed=1000,time=0.10322141647338867
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.04,seed=1000,time=0.18296122550964355
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.08,seed=1000,time=0.18124771118164062
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.12,seed=1000,time=0.16588902473449707
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.16,seed=1000,time=0.16912531852722168
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.2,seed=1000,time=0.09769558906555176
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.24,seed=1000,time=0.10863900184631348
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.28,seed=1000,time=0.08294367790222168
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.32,seed=1000,time=0.07922863960266113
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.36,seed=1000,time=0.08091092109680176
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.4,seed=1000,time=0.0801389217376709
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.0,seed=1000,time=0.28254055976867676
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.04,seed=1000,time=0.43993210792541504
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.08,seed=1000,time=0.37402892112731934
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.12,seed=1000,time=0.3047771453857422
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.16,seed=1000,time=0.2714657783508301
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.2,seed=1000,time=0.21287250518798828
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.24,seed=1000,time=0.1829056739807129
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.28,seed=1000,time=0.16736841201782227
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.32,seed=1000,time=0.18063640594482422
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.36,seed=1000,time=0.15412282943725586
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.4,seed=1000,time=0.17090439796447754
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.0,seed=1000,time=1.0253961086273193
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.04,seed=1000,time=1.4908781051635742
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.08,seed=1000,time=0.9772825241088867
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.12,seed=1000,time=0.793365478515625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.16,seed=1000,time=0.8063631057739258
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.2,seed=1000,time=0.5578813552856445
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.24,seed=1000,time=0.5330536365509033
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.28,seed=1000,time=0.5639817714691162
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.32,seed=1000,time=0.4890434741973877
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.36,seed=1000,time=0.48966169357299805
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.4,seed=1000,time=0.4567148685455322
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.0,seed=1000,time=2.7172601222991943
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.04,seed=1000,time=4.421621322631836
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.08,seed=1000,time=2.605269193649292
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.12,seed=1000,time=2.0095677375793457
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.16,seed=1000,time=1.807638168334961
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.2,seed=1000,time=1.3199479579925537
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.24,seed=1000,time=1.384648084640503
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.28,seed=1000,time=1.3976783752441406
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.32,seed=1000,time=1.271409511566162
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.36,seed=1000,time=1.1588435173034668
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.4,seed=1000,time=1.0579180717468262
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.0,seed=1000,time=40.18031120300293
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.04,seed=1000,time=57.43826913833618
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.08,seed=1000,time=25.0942440032959
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.12,seed=1000,time=16.77204155921936
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.16,seed=1000,time=16.307867527008057
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.2,seed=1000,time=14.46907901763916
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.24,seed=1000,time=13.992451429367065
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.28,seed=1000,time=13.07737112045288
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.32,seed=1000,time=13.082852602005005
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.36,seed=1000,time=12.614874124526978
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.4,seed=1000,time=12.047946214675903
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.0,seed=1000,time=113.92144107818604
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.04,seed=1000,time=143.23391699790955
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.08,seed=1000,time=84.2063524723053
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.12,seed=1000,time=64.25163173675537
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.16,seed=1000,time=47.565062522888184
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.2,seed=1000,time=50.64503598213196
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.24,seed=1000,time=52.936774492263794
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.28,seed=1000,time=47.46564865112305
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.32,seed=1000,time=48.48456525802612
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.36,seed=1000,time=43.23015570640564
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.4,seed=1000,time=43.021127223968506
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.0,seed=1000,time=0.013096094131469727
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.04,seed=1000,time=0.012784242630004883
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.08,seed=1000,time=0.006554841995239258
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.12,seed=1000,time=0.009238719940185547
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.16,seed=1000,time=0.008308887481689453
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.2,seed=1000,time=0.007680654525756836
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.24,seed=1000,time=0.009860515594482422
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.28,seed=1000,time=0.007364511489868164
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.32,seed=1000,time=0.0073320865631103516
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.36,seed=1000,time=0.00710296630859375
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.4,seed=1000,time=0.007299661636352539
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.0,seed=1000,time=0.06290674209594727
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.04,seed=1000,time=0.23676133155822754
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.08,seed=1000,time=0.12238931655883789
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.12,seed=1000,time=0.08278298377990723
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.16,seed=1000,time=0.07841038703918457
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.2,seed=1000,time=0.07077527046203613
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.24,seed=1000,time=0.058759212493896484
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.28,seed=1000,time=0.05419659614562988
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.32,seed=1000,time=0.045563697814941406
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.36,seed=1000,time=0.05217385292053223
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.4,seed=1000,time=0.04702472686767578
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.0,seed=1000,time=0.14136743545532227
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.04,seed=1000,time=0.6507000923156738
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.08,seed=1000,time=0.35295557975769043
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.12,seed=1000,time=0.29750895500183105
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.16,seed=1000,time=0.18280577659606934
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.2,seed=1000,time=0.16157126426696777
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.24,seed=1000,time=0.1557009220123291
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.28,seed=1000,time=0.14889931678771973
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.32,seed=1000,time=0.10093903541564941
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.36,seed=1000,time=0.09722185134887695
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.4,seed=1000,time=0.09359288215637207
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.0,seed=1000,time=0.4453258514404297
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.04,seed=1000,time=1.4681732654571533
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.08,seed=1000,time=0.8142974376678467
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.12,seed=1000,time=0.5948851108551025
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.16,seed=1000,time=0.3187251091003418
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.2,seed=1000,time=0.4273996353149414
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.24,seed=1000,time=0.3274350166320801
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.28,seed=1000,time=0.24742794036865234
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.32,seed=1000,time=0.2371056079864502
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.36,seed=1000,time=0.19939398765563965
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.4,seed=1000,time=0.1951756477355957
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.0,seed=1000,time=1.7701668739318848
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.04,seed=1000,time=6.537088394165039
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.08,seed=1000,time=3.8379478454589844
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.12,seed=1000,time=2.2439122200012207
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.16,seed=1000,time=1.2313671112060547
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.2,seed=1000,time=0.974311113357544
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.24,seed=1000,time=0.9588413238525391
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.28,seed=1000,time=0.815401554107666
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.32,seed=1000,time=0.7196338176727295
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.36,seed=1000,time=0.6296558380126953
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.4,seed=1000,time=0.6080825328826904
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.0,seed=1000,time=4.778851747512817
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.04,seed=1000,time=20.427220344543457
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.08,seed=1000,time=9.593631982803345
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.12,seed=1000,time=4.797768592834473
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.16,seed=1000,time=2.7094969749450684
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.2,seed=1000,time=2.427083730697632
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.24,seed=1000,time=1.7674121856689453
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.28,seed=1000,time=1.819223403930664
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.32,seed=1000,time=1.508481740951538
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.36,seed=1000,time=1.3906474113464355
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.4,seed=1000,time=1.2273988723754883
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.0,seed=1000,time=60.73726201057434
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.04,seed=1000,time=402.063884973526
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.08,seed=1000,time=92.01396036148071
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.12,seed=1000,time=31.910030364990234
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.16,seed=1000,time=22.353696823120117
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.2,seed=1000,time=17.85999846458435
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.24,seed=1000,time=16.154701232910156
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.28,seed=1000,time=14.144392967224121
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.32,seed=1000,time=14.201172351837158
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.36,seed=1000,time=12.33392333984375
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.4,seed=1000,time=11.838501930236816
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.0,seed=1000,time=370.53271532058716
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.04,seed=1000,time=2113.0203042030334
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.08,seed=1000,time=291.38346815109253
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.12,seed=1000,time=120.48564124107361
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.16,seed=1000,time=65.64164352416992
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.2,seed=1000,time=53.37838840484619
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.24,seed=1000,time=51.7885262966156
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.28,seed=1000,time=46.32713723182678
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.32,seed=1000,time=41.64993405342102
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.36,seed=1000,time=43.53005504608154
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.4,seed=1000,time=39.167964935302734
# Total time: 7749.269041061401
