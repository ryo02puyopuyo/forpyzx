# %%
import pyzx as zx
import random
from qiskit import QuantumCircuit
from qiskit.circuit import QuantumCircuit, ParameterVector
import csv
import time

# %%
def generate_H_S_CNOT_T_circuit(qubits, gates, p_t=0, seed=1000):
    random.seed(seed)  
    p_s = 0.333 * (1.0 - p_t)  
    p_had = 0.333 * (1.0 - p_t)  
    p_cnot = 0.333 * (1.0 - p_t)  

    c = zx.Circuit(qubits) 
    for _ in range(gates):
        r = random.random() 
        if r < p_had:
            c.add_gate("HAD", random.randrange(qubits))
        elif r < p_had + p_s:
            c.add_gate("S", random.randrange(qubits))
        elif r < p_had + p_s + p_t:
            c.add_gate("T", random.randrange(qubits))
        else:
            tgt = random.randrange(qubits)
            while True:
                ctrl = random.randrange(qubits)
                if ctrl != tgt:
                    break
            c.add_gate("CNOT", tgt, ctrl)
    return c

# %%
# seed固定
seed = 1002
random.seed(seed)

# パラメータ設定
qubits_list = [4, 8, 12, 16]
p_t_lists = [i * 0.04 for i in range(0, 11)]
gate_num_lists = [100, 500, 1000, 2000, 5000, 10000, 50000]

# CSV書き込みの準備
output_file = "../kekka1215/1215basic_50000_seed1002.csv"
fieldnames = [
    "optimize_name","data_name","gates","depth","t","H","otherRZ","CNOT","CZ","time"
]
start_all = time.time()
with open(output_file, "w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()


    for qubit in qubits_list:
        for gate_num in gate_num_lists:
            for p_t in p_t_lists:
                try:
                    start = time.time()
                    # 回路作成
                    c = generate_H_S_CNOT_T_circuit(qubits = qubit,gates= gate_num,p_t = p_t,seed = seed)
                    c = zx.optimize.basic_optimization(c)

                    end = time.time()

                    #qiskit変換とカウント
                    circuit_qiskit = QuantumCircuit.from_qasm_str(c.to_basic_gates().to_qasm())
                    depth = circuit_qiskit.depth()
                    zx_dict = c.to_basic_gates().stats_dict()
                    qiskit_dict = circuit_qiskit.count_ops()

                    optimize_name = "basic"
                    dataname = "q" + str(qubit) + "_gates" + str(gate_num) + "_pt" +str(p_t)+ "_seeds" + str(seed)
                    gates_aft = zx_dict["gates"]


                    # 結果をCSVに書き込む
                    writer.writerow({
                        "optimize_name": optimize_name,
                        "data_name": dataname,
                        "gates": gates_aft,
                        "depth": depth,
                        "t": zx_dict["tcount"],
                        "H": qiskit_dict.get("h", 0),
                        "otherRZ": gates_aft - qiskit_dict.get("h", 0) - qiskit_dict.get("cx", 0) - qiskit_dict.get("cz", 0) - zx_dict["tcount"],
                        "CNOT": qiskit_dict.get("cx", 0),
                        "CZ": qiskit_dict.get("cz", 0),
                        "time": end - start
                    })

                    print(f"done. Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t},seed={seed},time={end-start}")

                except Exception as e:
                    print(f"Error for Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t}: {e}")

end_all = time.time()
print(f"Total time: {end_all - start_all}")
# Out:
# done. Qubits=4, Gate_Num=100, P_T=0.0,seed=1002,time=0.004678964614868164
# done. Qubits=4, Gate_Num=100, P_T=0.04,seed=1002,time=0.0023813247680664062
# done. Qubits=4, Gate_Num=100, P_T=0.08,seed=1002,time=0.0021500587463378906
# done. Qubits=4, Gate_Num=100, P_T=0.12,seed=1002,time=0.0017638206481933594
# done. Qubits=4, Gate_Num=100, P_T=0.16,seed=1002,time=0.0018303394317626953
# done. Qubits=4, Gate_Num=100, P_T=0.2,seed=1002,time=0.0025331974029541016
# done. Qubits=4, Gate_Num=100, P_T=0.24,seed=1002,time=0.0018608570098876953
# done. Qubits=4, Gate_Num=100, P_T=0.28,seed=1002,time=0.002450704574584961
# done. Qubits=4, Gate_Num=100, P_T=0.32,seed=1002,time=0.0028846263885498047
# done. Qubits=4, Gate_Num=100, P_T=0.36,seed=1002,time=0.0023126602172851562
# done. Qubits=4, Gate_Num=100, P_T=0.4,seed=1002,time=0.0020771026611328125
# done. Qubits=4, Gate_Num=500, P_T=0.0,seed=1002,time=0.013270378112792969
# done. Qubits=4, Gate_Num=500, P_T=0.04,seed=1002,time=0.015858173370361328
# done. Qubits=4, Gate_Num=500, P_T=0.08,seed=1002,time=0.011349678039550781
# done. Qubits=4, Gate_Num=500, P_T=0.12,seed=1002,time=0.011408329010009766
# done. Qubits=4, Gate_Num=500, P_T=0.16,seed=1002,time=0.011134147644042969
# done. Qubits=4, Gate_Num=500, P_T=0.2,seed=1002,time=0.011492013931274414
# done. Qubits=4, Gate_Num=500, P_T=0.24,seed=1002,time=0.013408899307250977
# done. Qubits=4, Gate_Num=500, P_T=0.28,seed=1002,time=0.012456655502319336
# done. Qubits=4, Gate_Num=500, P_T=0.32,seed=1002,time=0.011464595794677734
# done. Qubits=4, Gate_Num=500, P_T=0.36,seed=1002,time=0.011389017105102539
# done. Qubits=4, Gate_Num=500, P_T=0.4,seed=1002,time=0.010765552520751953
# done. Qubits=4, Gate_Num=1000, P_T=0.0,seed=1002,time=0.029716014862060547
# done. Qubits=4, Gate_Num=1000, P_T=0.04,seed=1002,time=0.03202486038208008
# done. Qubits=4, Gate_Num=1000, P_T=0.08,seed=1002,time=0.03534364700317383
# done. Qubits=4, Gate_Num=1000, P_T=0.12,seed=1002,time=0.030742645263671875
# done. Qubits=4, Gate_Num=1000, P_T=0.16,seed=1002,time=0.027213573455810547
# done. Qubits=4, Gate_Num=1000, P_T=0.2,seed=1002,time=0.05576038360595703
# done. Qubits=4, Gate_Num=1000, P_T=0.24,seed=1002,time=0.033539772033691406
# done. Qubits=4, Gate_Num=1000, P_T=0.28,seed=1002,time=0.032413482666015625
# done. Qubits=4, Gate_Num=1000, P_T=0.32,seed=1002,time=0.027807950973510742
# done. Qubits=4, Gate_Num=1000, P_T=0.36,seed=1002,time=0.025713443756103516
# done. Qubits=4, Gate_Num=1000, P_T=0.4,seed=1002,time=0.026271581649780273
# done. Qubits=4, Gate_Num=2000, P_T=0.0,seed=1002,time=0.10211181640625
# done. Qubits=4, Gate_Num=2000, P_T=0.04,seed=1002,time=0.0837559700012207
# done. Qubits=4, Gate_Num=2000, P_T=0.08,seed=1002,time=0.09938335418701172
# done. Qubits=4, Gate_Num=2000, P_T=0.12,seed=1002,time=0.0858004093170166
# done. Qubits=4, Gate_Num=2000, P_T=0.16,seed=1002,time=0.07685708999633789
# done. Qubits=4, Gate_Num=2000, P_T=0.2,seed=1002,time=0.07334780693054199
# done. Qubits=4, Gate_Num=2000, P_T=0.24,seed=1002,time=0.08820676803588867
# done. Qubits=4, Gate_Num=2000, P_T=0.28,seed=1002,time=0.07802319526672363
# done. Qubits=4, Gate_Num=2000, P_T=0.32,seed=1002,time=0.07507920265197754
# done. Qubits=4, Gate_Num=2000, P_T=0.36,seed=1002,time=0.07489991188049316
# done. Qubits=4, Gate_Num=2000, P_T=0.4,seed=1002,time=0.09602975845336914
# done. Qubits=4, Gate_Num=5000, P_T=0.0,seed=1002,time=0.2866702079772949
# done. Qubits=4, Gate_Num=5000, P_T=0.04,seed=1002,time=0.34557318687438965
# done. Qubits=4, Gate_Num=5000, P_T=0.08,seed=1002,time=0.4255690574645996
# done. Qubits=4, Gate_Num=5000, P_T=0.12,seed=1002,time=0.3333256244659424
# done. Qubits=4, Gate_Num=5000, P_T=0.16,seed=1002,time=0.30724215507507324
# done. Qubits=4, Gate_Num=5000, P_T=0.2,seed=1002,time=0.34423041343688965
# done. Qubits=4, Gate_Num=5000, P_T=0.24,seed=1002,time=0.3841285705566406
# done. Qubits=4, Gate_Num=5000, P_T=0.28,seed=1002,time=0.35994410514831543
# done. Qubits=4, Gate_Num=5000, P_T=0.32,seed=1002,time=0.3034813404083252
# done. Qubits=4, Gate_Num=5000, P_T=0.36,seed=1002,time=0.32474231719970703
# done. Qubits=4, Gate_Num=5000, P_T=0.4,seed=1002,time=0.31630492210388184
# done. Qubits=4, Gate_Num=10000, P_T=0.0,seed=1002,time=1.234773874282837
# done. Qubits=4, Gate_Num=10000, P_T=0.04,seed=1002,time=1.1979613304138184
# done. Qubits=4, Gate_Num=10000, P_T=0.08,seed=1002,time=1.0241448879241943
# done. Qubits=4, Gate_Num=10000, P_T=0.12,seed=1002,time=1.0982255935668945
# done. Qubits=4, Gate_Num=10000, P_T=0.16,seed=1002,time=1.0802998542785645
# done. Qubits=4, Gate_Num=10000, P_T=0.2,seed=1002,time=1.0479803085327148
# done. Qubits=4, Gate_Num=10000, P_T=0.24,seed=1002,time=0.9901480674743652
# done. Qubits=4, Gate_Num=10000, P_T=0.28,seed=1002,time=0.9986324310302734
# done. Qubits=4, Gate_Num=10000, P_T=0.32,seed=1002,time=1.0922462940216064
# done. Qubits=4, Gate_Num=10000, P_T=0.36,seed=1002,time=1.0123405456542969
# done. Qubits=4, Gate_Num=10000, P_T=0.4,seed=1002,time=0.994257926940918
# done. Qubits=4, Gate_Num=50000, P_T=0.0,seed=1002,time=24.864448070526123
# done. Qubits=4, Gate_Num=50000, P_T=0.04,seed=1002,time=25.945508241653442
# done. Qubits=4, Gate_Num=50000, P_T=0.08,seed=1002,time=26.43599009513855
# done. Qubits=4, Gate_Num=50000, P_T=0.12,seed=1002,time=25.536375761032104
# done. Qubits=4, Gate_Num=50000, P_T=0.16,seed=1002,time=26.24265146255493
# done. Qubits=4, Gate_Num=50000, P_T=0.2,seed=1002,time=23.83780598640442
# done. Qubits=4, Gate_Num=50000, P_T=0.24,seed=1002,time=23.822672605514526
# done. Qubits=4, Gate_Num=50000, P_T=0.28,seed=1002,time=22.436310291290283
# done. Qubits=4, Gate_Num=50000, P_T=0.32,seed=1002,time=25.32949686050415
# done. Qubits=4, Gate_Num=50000, P_T=0.36,seed=1002,time=22.25586748123169
# done. Qubits=4, Gate_Num=50000, P_T=0.4,seed=1002,time=22.7477445602417
# done. Qubits=8, Gate_Num=100, P_T=0.0,seed=1002,time=0.0030362606048583984
# done. Qubits=8, Gate_Num=100, P_T=0.04,seed=1002,time=0.0016498565673828125
# done. Qubits=8, Gate_Num=100, P_T=0.08,seed=1002,time=0.0015993118286132812
# done. Qubits=8, Gate_Num=100, P_T=0.12,seed=1002,time=0.0015926361083984375
# done. Qubits=8, Gate_Num=100, P_T=0.16,seed=1002,time=0.0017342567443847656
# done. Qubits=8, Gate_Num=100, P_T=0.2,seed=1002,time=0.0014789104461669922
# done. Qubits=8, Gate_Num=100, P_T=0.24,seed=1002,time=0.001984119415283203
# done. Qubits=8, Gate_Num=100, P_T=0.28,seed=1002,time=0.002143383026123047
# done. Qubits=8, Gate_Num=100, P_T=0.32,seed=1002,time=0.001941680908203125
# done. Qubits=8, Gate_Num=100, P_T=0.36,seed=1002,time=0.002614259719848633
# done. Qubits=8, Gate_Num=100, P_T=0.4,seed=1002,time=0.0015873908996582031
# done. Qubits=8, Gate_Num=500, P_T=0.0,seed=1002,time=0.012835264205932617
# done. Qubits=8, Gate_Num=500, P_T=0.04,seed=1002,time=0.01240086555480957
# done. Qubits=8, Gate_Num=500, P_T=0.08,seed=1002,time=0.012655496597290039
# done. Qubits=8, Gate_Num=500, P_T=0.12,seed=1002,time=0.012483358383178711
# done. Qubits=8, Gate_Num=500, P_T=0.16,seed=1002,time=0.013161182403564453
# done. Qubits=8, Gate_Num=500, P_T=0.2,seed=1002,time=0.012954950332641602
# done. Qubits=8, Gate_Num=500, P_T=0.24,seed=1002,time=0.012352466583251953
# done. Qubits=8, Gate_Num=500, P_T=0.28,seed=1002,time=0.011845111846923828
# done. Qubits=8, Gate_Num=500, P_T=0.32,seed=1002,time=0.012254476547241211
# done. Qubits=8, Gate_Num=500, P_T=0.36,seed=1002,time=0.011986494064331055
# done. Qubits=8, Gate_Num=500, P_T=0.4,seed=1002,time=0.011391639709472656
# done. Qubits=8, Gate_Num=1000, P_T=0.0,seed=1002,time=0.02642655372619629
# done. Qubits=8, Gate_Num=1000, P_T=0.04,seed=1002,time=0.02907729148864746
# done. Qubits=8, Gate_Num=1000, P_T=0.08,seed=1002,time=0.033631086349487305
# done. Qubits=8, Gate_Num=1000, P_T=0.12,seed=1002,time=0.03119945526123047
# done. Qubits=8, Gate_Num=1000, P_T=0.16,seed=1002,time=0.031116008758544922
# done. Qubits=8, Gate_Num=1000, P_T=0.2,seed=1002,time=0.030881881713867188
# done. Qubits=8, Gate_Num=1000, P_T=0.24,seed=1002,time=0.029567718505859375
# done. Qubits=8, Gate_Num=1000, P_T=0.28,seed=1002,time=0.025836467742919922
# done. Qubits=8, Gate_Num=1000, P_T=0.32,seed=1002,time=0.031020641326904297
# done. Qubits=8, Gate_Num=1000, P_T=0.36,seed=1002,time=0.025034189224243164
# done. Qubits=8, Gate_Num=1000, P_T=0.4,seed=1002,time=0.023496389389038086
# done. Qubits=8, Gate_Num=2000, P_T=0.0,seed=1002,time=0.08485674858093262
# done. Qubits=8, Gate_Num=2000, P_T=0.04,seed=1002,time=0.06418704986572266
# done. Qubits=8, Gate_Num=2000, P_T=0.08,seed=1002,time=0.06521368026733398
# done. Qubits=8, Gate_Num=2000, P_T=0.12,seed=1002,time=0.055676937103271484
# done. Qubits=8, Gate_Num=2000, P_T=0.16,seed=1002,time=0.07619071006774902
# done. Qubits=8, Gate_Num=2000, P_T=0.2,seed=1002,time=0.06530332565307617
# done. Qubits=8, Gate_Num=2000, P_T=0.24,seed=1002,time=0.05592679977416992
# done. Qubits=8, Gate_Num=2000, P_T=0.28,seed=1002,time=0.05441474914550781
# done. Qubits=8, Gate_Num=2000, P_T=0.32,seed=1002,time=0.09126615524291992
# done. Qubits=8, Gate_Num=2000, P_T=0.36,seed=1002,time=0.05485653877258301
# done. Qubits=8, Gate_Num=2000, P_T=0.4,seed=1002,time=0.052706003189086914
# done. Qubits=8, Gate_Num=5000, P_T=0.0,seed=1002,time=0.23378682136535645
# done. Qubits=8, Gate_Num=5000, P_T=0.04,seed=1002,time=0.23526716232299805
# done. Qubits=8, Gate_Num=5000, P_T=0.08,seed=1002,time=0.22565150260925293
# done. Qubits=8, Gate_Num=5000, P_T=0.12,seed=1002,time=0.22374844551086426
# done. Qubits=8, Gate_Num=5000, P_T=0.16,seed=1002,time=0.22306203842163086
# done. Qubits=8, Gate_Num=5000, P_T=0.2,seed=1002,time=0.2203977108001709
# done. Qubits=8, Gate_Num=5000, P_T=0.24,seed=1002,time=0.22805476188659668
# done. Qubits=8, Gate_Num=5000, P_T=0.28,seed=1002,time=0.18198609352111816
# done. Qubits=8, Gate_Num=5000, P_T=0.32,seed=1002,time=0.22613263130187988
# done. Qubits=8, Gate_Num=5000, P_T=0.36,seed=1002,time=0.22302556037902832
# done. Qubits=8, Gate_Num=5000, P_T=0.4,seed=1002,time=0.17868995666503906
# done. Qubits=8, Gate_Num=10000, P_T=0.0,seed=1002,time=0.61106276512146
# done. Qubits=8, Gate_Num=10000, P_T=0.04,seed=1002,time=0.6483128070831299
# done. Qubits=8, Gate_Num=10000, P_T=0.08,seed=1002,time=0.7124888896942139
# done. Qubits=8, Gate_Num=10000, P_T=0.12,seed=1002,time=0.6836020946502686
# done. Qubits=8, Gate_Num=10000, P_T=0.16,seed=1002,time=0.6351065635681152
# done. Qubits=8, Gate_Num=10000, P_T=0.2,seed=1002,time=0.6429212093353271
# done. Qubits=8, Gate_Num=10000, P_T=0.24,seed=1002,time=0.6238713264465332
# done. Qubits=8, Gate_Num=10000, P_T=0.28,seed=1002,time=0.6122775077819824
# done. Qubits=8, Gate_Num=10000, P_T=0.32,seed=1002,time=0.8912472724914551
# done. Qubits=8, Gate_Num=10000, P_T=0.36,seed=1002,time=0.6865289211273193
# done. Qubits=8, Gate_Num=10000, P_T=0.4,seed=1002,time=0.6151549816131592
# done. Qubits=8, Gate_Num=50000, P_T=0.0,seed=1002,time=12.05737018585205
# done. Qubits=8, Gate_Num=50000, P_T=0.04,seed=1002,time=14.778452157974243
# done. Qubits=8, Gate_Num=50000, P_T=0.08,seed=1002,time=13.434671878814697
# done. Qubits=8, Gate_Num=50000, P_T=0.12,seed=1002,time=12.036030292510986
# done. Qubits=8, Gate_Num=50000, P_T=0.16,seed=1002,time=14.750250577926636
# done. Qubits=8, Gate_Num=50000, P_T=0.2,seed=1002,time=18.177175760269165
# done. Qubits=8, Gate_Num=50000, P_T=0.24,seed=1002,time=15.073481798171997
# done. Qubits=8, Gate_Num=50000, P_T=0.28,seed=1002,time=14.113946676254272
# done. Qubits=8, Gate_Num=50000, P_T=0.32,seed=1002,time=12.519453763961792
# done. Qubits=8, Gate_Num=50000, P_T=0.36,seed=1002,time=12.866004467010498
# done. Qubits=8, Gate_Num=50000, P_T=0.4,seed=1002,time=13.499720335006714
# done. Qubits=12, Gate_Num=100, P_T=0.0,seed=1002,time=0.0032007694244384766
# done. Qubits=12, Gate_Num=100, P_T=0.04,seed=1002,time=0.0015804767608642578
# done. Qubits=12, Gate_Num=100, P_T=0.08,seed=1002,time=0.0015194416046142578
# done. Qubits=12, Gate_Num=100, P_T=0.12,seed=1002,time=0.0018718242645263672
# done. Qubits=12, Gate_Num=100, P_T=0.16,seed=1002,time=0.001699686050415039
# done. Qubits=12, Gate_Num=100, P_T=0.2,seed=1002,time=0.0016179084777832031
# done. Qubits=12, Gate_Num=100, P_T=0.24,seed=1002,time=0.0015494823455810547
# done. Qubits=12, Gate_Num=100, P_T=0.28,seed=1002,time=0.001514434814453125
# done. Qubits=12, Gate_Num=100, P_T=0.32,seed=1002,time=0.001535654067993164
# done. Qubits=12, Gate_Num=100, P_T=0.36,seed=1002,time=0.0016617774963378906
# done. Qubits=12, Gate_Num=100, P_T=0.4,seed=1002,time=0.0017971992492675781
# done. Qubits=12, Gate_Num=500, P_T=0.0,seed=1002,time=0.0178680419921875
# done. Qubits=12, Gate_Num=500, P_T=0.04,seed=1002,time=0.014461517333984375
# done. Qubits=12, Gate_Num=500, P_T=0.08,seed=1002,time=0.014582395553588867
# done. Qubits=12, Gate_Num=500, P_T=0.12,seed=1002,time=0.01120448112487793
# done. Qubits=12, Gate_Num=500, P_T=0.16,seed=1002,time=0.010074138641357422
# done. Qubits=12, Gate_Num=500, P_T=0.2,seed=1002,time=0.010085105895996094
# done. Qubits=12, Gate_Num=500, P_T=0.24,seed=1002,time=0.009556055068969727
# done. Qubits=12, Gate_Num=500, P_T=0.28,seed=1002,time=0.010139226913452148
# done. Qubits=12, Gate_Num=500, P_T=0.32,seed=1002,time=0.007573604583740234
# done. Qubits=12, Gate_Num=500, P_T=0.36,seed=1002,time=0.007332324981689453
# done. Qubits=12, Gate_Num=500, P_T=0.4,seed=1002,time=0.010094165802001953
# done. Qubits=12, Gate_Num=1000, P_T=0.0,seed=1002,time=0.03565192222595215
# done. Qubits=12, Gate_Num=1000, P_T=0.04,seed=1002,time=0.030088186264038086
# done. Qubits=12, Gate_Num=1000, P_T=0.08,seed=1002,time=0.029542207717895508
# done. Qubits=12, Gate_Num=1000, P_T=0.12,seed=1002,time=0.02803349494934082
# done. Qubits=12, Gate_Num=1000, P_T=0.16,seed=1002,time=0.029658079147338867
# done. Qubits=12, Gate_Num=1000, P_T=0.2,seed=1002,time=0.024761676788330078
# done. Qubits=12, Gate_Num=1000, P_T=0.24,seed=1002,time=0.024594783782958984
# done. Qubits=12, Gate_Num=1000, P_T=0.28,seed=1002,time=0.02417778968811035
# done. Qubits=12, Gate_Num=1000, P_T=0.32,seed=1002,time=0.05814361572265625
# done. Qubits=12, Gate_Num=1000, P_T=0.36,seed=1002,time=0.02674579620361328
# done. Qubits=12, Gate_Num=1000, P_T=0.4,seed=1002,time=0.027147293090820312
# done. Qubits=12, Gate_Num=2000, P_T=0.0,seed=1002,time=0.07132697105407715
# done. Qubits=12, Gate_Num=2000, P_T=0.04,seed=1002,time=0.05786943435668945
# done. Qubits=12, Gate_Num=2000, P_T=0.08,seed=1002,time=0.05877280235290527
# done. Qubits=12, Gate_Num=2000, P_T=0.12,seed=1002,time=0.08289980888366699
# done. Qubits=12, Gate_Num=2000, P_T=0.16,seed=1002,time=0.0589449405670166
# done. Qubits=12, Gate_Num=2000, P_T=0.2,seed=1002,time=0.058937788009643555
# done. Qubits=12, Gate_Num=2000, P_T=0.24,seed=1002,time=0.05517983436584473
# done. Qubits=12, Gate_Num=2000, P_T=0.28,seed=1002,time=0.08027386665344238
# done. Qubits=12, Gate_Num=2000, P_T=0.32,seed=1002,time=0.052649497985839844
# done. Qubits=12, Gate_Num=2000, P_T=0.36,seed=1002,time=0.05145597457885742
# done. Qubits=12, Gate_Num=2000, P_T=0.4,seed=1002,time=0.049248695373535156
# done. Qubits=12, Gate_Num=5000, P_T=0.0,seed=1002,time=0.21318888664245605
# done. Qubits=12, Gate_Num=5000, P_T=0.04,seed=1002,time=0.2395615577697754
# done. Qubits=12, Gate_Num=5000, P_T=0.08,seed=1002,time=0.23265552520751953
# done. Qubits=12, Gate_Num=5000, P_T=0.12,seed=1002,time=0.1824326515197754
# done. Qubits=12, Gate_Num=5000, P_T=0.16,seed=1002,time=0.2060079574584961
# done. Qubits=12, Gate_Num=5000, P_T=0.2,seed=1002,time=0.18657708168029785
# done. Qubits=12, Gate_Num=5000, P_T=0.24,seed=1002,time=0.1914665699005127
# done. Qubits=12, Gate_Num=5000, P_T=0.28,seed=1002,time=0.17782235145568848
# done. Qubits=12, Gate_Num=5000, P_T=0.32,seed=1002,time=0.1801927089691162
# done. Qubits=12, Gate_Num=5000, P_T=0.36,seed=1002,time=0.17750191688537598
# done. Qubits=12, Gate_Num=5000, P_T=0.4,seed=1002,time=0.1975264549255371
# done. Qubits=12, Gate_Num=10000, P_T=0.0,seed=1002,time=0.664790153503418
# done. Qubits=12, Gate_Num=10000, P_T=0.04,seed=1002,time=0.5170817375183105
# done. Qubits=12, Gate_Num=10000, P_T=0.08,seed=1002,time=0.6404597759246826
# done. Qubits=12, Gate_Num=10000, P_T=0.12,seed=1002,time=0.5970981121063232
# done. Qubits=12, Gate_Num=10000, P_T=0.16,seed=1002,time=0.5177216529846191
# done. Qubits=12, Gate_Num=10000, P_T=0.2,seed=1002,time=0.5853374004364014
# done. Qubits=12, Gate_Num=10000, P_T=0.24,seed=1002,time=0.5944089889526367
# done. Qubits=12, Gate_Num=10000, P_T=0.28,seed=1002,time=0.4704451560974121
# done. Qubits=12, Gate_Num=10000, P_T=0.32,seed=1002,time=0.5096116065979004
# done. Qubits=12, Gate_Num=10000, P_T=0.36,seed=1002,time=0.547433614730835
# done. Qubits=12, Gate_Num=10000, P_T=0.4,seed=1002,time=0.4977595806121826
# done. Qubits=12, Gate_Num=50000, P_T=0.0,seed=1002,time=10.149879455566406
# done. Qubits=12, Gate_Num=50000, P_T=0.04,seed=1002,time=10.71924614906311
# done. Qubits=12, Gate_Num=50000, P_T=0.08,seed=1002,time=11.382987260818481
# done. Qubits=12, Gate_Num=50000, P_T=0.12,seed=1002,time=8.364197492599487
# done. Qubits=12, Gate_Num=50000, P_T=0.16,seed=1002,time=10.286088705062866
# done. Qubits=12, Gate_Num=50000, P_T=0.2,seed=1002,time=10.763838291168213
# done. Qubits=12, Gate_Num=50000, P_T=0.24,seed=1002,time=10.313047409057617
# done. Qubits=12, Gate_Num=50000, P_T=0.28,seed=1002,time=8.271875381469727
# done. Qubits=12, Gate_Num=50000, P_T=0.32,seed=1002,time=8.30901050567627
# done. Qubits=12, Gate_Num=50000, P_T=0.36,seed=1002,time=9.055568218231201
# done. Qubits=12, Gate_Num=50000, P_T=0.4,seed=1002,time=7.9830005168914795
# done. Qubits=16, Gate_Num=100, P_T=0.0,seed=1002,time=0.0032134056091308594
# done. Qubits=16, Gate_Num=100, P_T=0.04,seed=1002,time=0.0018432140350341797
# done. Qubits=16, Gate_Num=100, P_T=0.08,seed=1002,time=0.0017070770263671875
# done. Qubits=16, Gate_Num=100, P_T=0.12,seed=1002,time=0.0017309188842773438
# done. Qubits=16, Gate_Num=100, P_T=0.16,seed=1002,time=0.001722574234008789
# done. Qubits=16, Gate_Num=100, P_T=0.2,seed=1002,time=0.0016796588897705078
# done. Qubits=16, Gate_Num=100, P_T=0.24,seed=1002,time=0.002180337905883789
# done. Qubits=16, Gate_Num=100, P_T=0.28,seed=1002,time=0.0018842220306396484
# done. Qubits=16, Gate_Num=100, P_T=0.32,seed=1002,time=0.0017693042755126953
# done. Qubits=16, Gate_Num=100, P_T=0.36,seed=1002,time=0.00284576416015625
# done. Qubits=16, Gate_Num=100, P_T=0.4,seed=1002,time=0.0028076171875
# done. Qubits=16, Gate_Num=500, P_T=0.0,seed=1002,time=0.011915445327758789
# done. Qubits=16, Gate_Num=500, P_T=0.04,seed=1002,time=0.014869928359985352
# done. Qubits=16, Gate_Num=500, P_T=0.08,seed=1002,time=0.012149810791015625
# done. Qubits=16, Gate_Num=500, P_T=0.12,seed=1002,time=0.008810997009277344
# done. Qubits=16, Gate_Num=500, P_T=0.16,seed=1002,time=0.012282133102416992
# done. Qubits=16, Gate_Num=500, P_T=0.2,seed=1002,time=0.010885477066040039
# done. Qubits=16, Gate_Num=500, P_T=0.24,seed=1002,time=0.008783817291259766
# done. Qubits=16, Gate_Num=500, P_T=0.28,seed=1002,time=0.011282682418823242
# done. Qubits=16, Gate_Num=500, P_T=0.32,seed=1002,time=0.01054239273071289
# done. Qubits=16, Gate_Num=500, P_T=0.36,seed=1002,time=0.012472152709960938
# done. Qubits=16, Gate_Num=500, P_T=0.4,seed=1002,time=0.011924028396606445
# done. Qubits=16, Gate_Num=1000, P_T=0.0,seed=1002,time=0.028125762939453125
# done. Qubits=16, Gate_Num=1000, P_T=0.04,seed=1002,time=0.029942750930786133
# done. Qubits=16, Gate_Num=1000, P_T=0.08,seed=1002,time=0.054319143295288086
# done. Qubits=16, Gate_Num=1000, P_T=0.12,seed=1002,time=0.023661375045776367
# done. Qubits=16, Gate_Num=1000, P_T=0.16,seed=1002,time=0.03307533264160156
# done. Qubits=16, Gate_Num=1000, P_T=0.2,seed=1002,time=0.026248455047607422
# done. Qubits=16, Gate_Num=1000, P_T=0.24,seed=1002,time=0.020968198776245117
# done. Qubits=16, Gate_Num=1000, P_T=0.28,seed=1002,time=0.020706653594970703
# done. Qubits=16, Gate_Num=1000, P_T=0.32,seed=1002,time=0.020903348922729492
# done. Qubits=16, Gate_Num=1000, P_T=0.36,seed=1002,time=0.024534225463867188
# done. Qubits=16, Gate_Num=1000, P_T=0.4,seed=1002,time=0.023342132568359375
# done. Qubits=16, Gate_Num=2000, P_T=0.0,seed=1002,time=0.05902528762817383
# done. Qubits=16, Gate_Num=2000, P_T=0.04,seed=1002,time=0.09464740753173828
# done. Qubits=16, Gate_Num=2000, P_T=0.08,seed=1002,time=0.06887435913085938
# done. Qubits=16, Gate_Num=2000, P_T=0.12,seed=1002,time=0.06819725036621094
# done. Qubits=16, Gate_Num=2000, P_T=0.16,seed=1002,time=0.07991909980773926
# done. Qubits=16, Gate_Num=2000, P_T=0.2,seed=1002,time=0.05496716499328613
# done. Qubits=16, Gate_Num=2000, P_T=0.24,seed=1002,time=0.055782318115234375
# done. Qubits=16, Gate_Num=2000, P_T=0.28,seed=1002,time=0.05130600929260254
# done. Qubits=16, Gate_Num=2000, P_T=0.32,seed=1002,time=0.07737493515014648
# done. Qubits=16, Gate_Num=2000, P_T=0.36,seed=1002,time=0.052153825759887695
# done. Qubits=16, Gate_Num=2000, P_T=0.4,seed=1002,time=0.05112099647521973
# done. Qubits=16, Gate_Num=5000, P_T=0.0,seed=1002,time=0.1819758415222168
# done. Qubits=16, Gate_Num=5000, P_T=0.04,seed=1002,time=0.15696096420288086
# done. Qubits=16, Gate_Num=5000, P_T=0.08,seed=1002,time=0.18312835693359375
# done. Qubits=16, Gate_Num=5000, P_T=0.12,seed=1002,time=0.2123706340789795
# done. Qubits=16, Gate_Num=5000, P_T=0.16,seed=1002,time=0.20185637474060059
# done. Qubits=16, Gate_Num=5000, P_T=0.2,seed=1002,time=0.15564560890197754
# done. Qubits=16, Gate_Num=5000, P_T=0.24,seed=1002,time=0.17704463005065918
# done. Qubits=16, Gate_Num=5000, P_T=0.28,seed=1002,time=0.1807410717010498
# done. Qubits=16, Gate_Num=5000, P_T=0.32,seed=1002,time=0.15683412551879883
# done. Qubits=16, Gate_Num=5000, P_T=0.36,seed=1002,time=0.17850232124328613
# done. Qubits=16, Gate_Num=5000, P_T=0.4,seed=1002,time=0.1711902618408203
# done. Qubits=16, Gate_Num=10000, P_T=0.0,seed=1002,time=0.524867057800293
# done. Qubits=16, Gate_Num=10000, P_T=0.04,seed=1002,time=0.5090086460113525
# done. Qubits=16, Gate_Num=10000, P_T=0.08,seed=1002,time=0.40383386611938477
# done. Qubits=16, Gate_Num=10000, P_T=0.12,seed=1002,time=0.48746252059936523
# done. Qubits=16, Gate_Num=10000, P_T=0.16,seed=1002,time=0.5387005805969238
# done. Qubits=16, Gate_Num=10000, P_T=0.2,seed=1002,time=0.4572174549102783
# done. Qubits=16, Gate_Num=10000, P_T=0.24,seed=1002,time=0.4252336025238037
# done. Qubits=16, Gate_Num=10000, P_T=0.28,seed=1002,time=0.4052278995513916
# done. Qubits=16, Gate_Num=10000, P_T=0.32,seed=1002,time=0.4073946475982666
# done. Qubits=16, Gate_Num=10000, P_T=0.36,seed=1002,time=0.47623157501220703
# done. Qubits=16, Gate_Num=10000, P_T=0.4,seed=1002,time=0.49169254302978516
# done. Qubits=16, Gate_Num=50000, P_T=0.0,seed=1002,time=8.318466901779175
# done. Qubits=16, Gate_Num=50000, P_T=0.04,seed=1002,time=7.213489294052124
# done. Qubits=16, Gate_Num=50000, P_T=0.08,seed=1002,time=9.317240238189697
# done. Qubits=16, Gate_Num=50000, P_T=0.12,seed=1002,time=7.548707962036133
# done. Qubits=16, Gate_Num=50000, P_T=0.16,seed=1002,time=7.640235662460327
# done. Qubits=16, Gate_Num=50000, P_T=0.2,seed=1002,time=8.018795251846313
# done. Qubits=16, Gate_Num=50000, P_T=0.24,seed=1002,time=7.423224449157715
# done. Qubits=16, Gate_Num=50000, P_T=0.28,seed=1002,time=6.94775390625
# done. Qubits=16, Gate_Num=50000, P_T=0.32,seed=1002,time=6.933051347732544
# done. Qubits=16, Gate_Num=50000, P_T=0.36,seed=1002,time=7.081531763076782
# done. Qubits=16, Gate_Num=50000, P_T=0.4,seed=1002,time=6.39225959777832
# Total time: 666.3011543750763
