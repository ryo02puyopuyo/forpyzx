# %%
import pyzx as zx
import random
from qiskit import QuantumCircuit
from qiskit.circuit import QuantumCircuit, ParameterVector
import csv
import time

# %%
def generate_H_S_CNOT_T_circuit(qubits, gates, p_t=0, seed=1000):
    random.seed(seed)  
    p_s = 0.333 * (1.0 - p_t)  
    p_had = 0.333 * (1.0 - p_t)  
    p_cnot = 0.333 * (1.0 - p_t)  

    c = zx.Circuit(qubits) 
    for _ in range(gates):
        r = random.random() 
        if r < p_had:
            c.add_gate("HAD", random.randrange(qubits))
        elif r < p_had + p_s:
            c.add_gate("S", random.randrange(qubits))
        elif r < p_had + p_s + p_t:
            c.add_gate("T", random.randrange(qubits))
        else:
            tgt = random.randrange(qubits)
            while True:
                ctrl = random.randrange(qubits)
                if ctrl != tgt:
                    break
            c.add_gate("CNOT", tgt, ctrl)
    return c

# %%
# seed固定
seed = 1000
random.seed(seed)

# パラメータ設定
qubits_list = [4, 8, 12, 16]
p_t_lists = [i * 0.04 for i in range(0, 11)]
gate_num_lists = [100, 500, 1000, 2000, 5000, 10000, 50000,100000]

# CSV書き込みの準備
output_file = "../kekka/basic_100000.csv"
fieldnames = [
    "optimize_name","data_name","gates","depth","t","H","otherRZ","CNOT","CZ","time"
]
start_all = time.time()
with open(output_file, "w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()



    for qubit in qubits_list:
        for gate_num in gate_num_lists:
            for p_t in p_t_lists:
                try:
                    start = time.time()
                    # 回路作成
                    c = generate_H_S_CNOT_T_circuit(qubits = qubit,gates= gate_num,p_t = p_t,seed = seed)
                    c = zx.optimize.basic_optimization(c)

                    end = time.time()

                    #qiskit変換とカウント
                    circuit_qiskit = QuantumCircuit.from_qasm_str(c.to_basic_gates().to_qasm())
                    depth = circuit_qiskit.depth()
                    zx_dict = c.to_basic_gates().stats_dict()
                    qiskit_dict = circuit_qiskit.count_ops()

                    optimize_name = "basic"
                    dataname = "q" + str(qubit) + "_gates" + str(gate_num) + "_pt" +str(p_t)+ "_seeds" + str(seed)
                    gates_aft = zx_dict["gates"]


                    # 結果をCSVに書き込む
                    writer.writerow({
                        "optimize_name": optimize_name,
                        "data_name": dataname,
                        "gates": gates_aft,
                        "depth": depth,
                        "t": zx_dict["tcount"],
                        "H": qiskit_dict.get("h", 0),
                        "otherRZ": gates_aft - qiskit_dict.get("h", 0) - qiskit_dict.get("cx", 0) - qiskit_dict.get("cz", 0) - zx_dict["tcount"],
                        "CNOT": qiskit_dict.get("cx", 0),
                        "CZ": qiskit_dict.get("cz", 0),
                        "time": end - start
                    })

                    print(f"done. Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t},seed={seed},time={end-start}")

                except Exception as e:
                    print(f"Error for Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t}: {e}")

end_all = time.time()
print(f"Total time: {end_all - start_all}")
# Out:
# done. Qubits=4, Gate_Num=100, P_T=0.0,seed=1000,time=0.0026264190673828125
# done. Qubits=4, Gate_Num=100, P_T=0.04,seed=1000,time=0.0031273365020751953
# done. Qubits=4, Gate_Num=100, P_T=0.08,seed=1000,time=0.004224300384521484
# done. Qubits=4, Gate_Num=100, P_T=0.12,seed=1000,time=0.00299072265625
# done. Qubits=4, Gate_Num=100, P_T=0.16,seed=1000,time=0.0025708675384521484
# done. Qubits=4, Gate_Num=100, P_T=0.2,seed=1000,time=0.0022246837615966797
# done. Qubits=4, Gate_Num=100, P_T=0.24,seed=1000,time=0.00274658203125
# done. Qubits=4, Gate_Num=100, P_T=0.28,seed=1000,time=0.0025420188903808594
# done. Qubits=4, Gate_Num=100, P_T=0.32,seed=1000,time=0.0019271373748779297
# done. Qubits=4, Gate_Num=100, P_T=0.36,seed=1000,time=0.0025167465209960938
# done. Qubits=4, Gate_Num=100, P_T=0.4,seed=1000,time=0.002320528030395508
# done. Qubits=4, Gate_Num=500, P_T=0.0,seed=1000,time=0.017704486846923828
# done. Qubits=4, Gate_Num=500, P_T=0.04,seed=1000,time=0.015846967697143555
# done. Qubits=4, Gate_Num=500, P_T=0.08,seed=1000,time=0.01241159439086914
# done. Qubits=4, Gate_Num=500, P_T=0.12,seed=1000,time=0.014903783798217773
# done. Qubits=4, Gate_Num=500, P_T=0.16,seed=1000,time=0.014740705490112305
# done. Qubits=4, Gate_Num=500, P_T=0.2,seed=1000,time=0.01455235481262207
# done. Qubits=4, Gate_Num=500, P_T=0.24,seed=1000,time=0.01201009750366211
# done. Qubits=4, Gate_Num=500, P_T=0.28,seed=1000,time=0.01270294189453125
# done. Qubits=4, Gate_Num=500, P_T=0.32,seed=1000,time=0.009504079818725586
# done. Qubits=4, Gate_Num=500, P_T=0.36,seed=1000,time=0.012152671813964844
# done. Qubits=4, Gate_Num=500, P_T=0.4,seed=1000,time=0.05093669891357422
# done. Qubits=4, Gate_Num=1000, P_T=0.0,seed=1000,time=0.052759647369384766
# done. Qubits=4, Gate_Num=1000, P_T=0.04,seed=1000,time=0.034087181091308594
# done. Qubits=4, Gate_Num=1000, P_T=0.08,seed=1000,time=0.02895188331604004
# done. Qubits=4, Gate_Num=1000, P_T=0.12,seed=1000,time=0.029500246047973633
# done. Qubits=4, Gate_Num=1000, P_T=0.16,seed=1000,time=0.03292536735534668
# done. Qubits=4, Gate_Num=1000, P_T=0.2,seed=1000,time=0.030544281005859375
# done. Qubits=4, Gate_Num=1000, P_T=0.24,seed=1000,time=0.03453969955444336
# done. Qubits=4, Gate_Num=1000, P_T=0.28,seed=1000,time=0.02972102165222168
# done. Qubits=4, Gate_Num=1000, P_T=0.32,seed=1000,time=0.02754950523376465
# done. Qubits=4, Gate_Num=1000, P_T=0.36,seed=1000,time=0.06294131278991699
# done. Qubits=4, Gate_Num=1000, P_T=0.4,seed=1000,time=0.026646852493286133
# done. Qubits=4, Gate_Num=2000, P_T=0.0,seed=1000,time=0.08934760093688965
# done. Qubits=4, Gate_Num=2000, P_T=0.04,seed=1000,time=0.0931401252746582
# done. Qubits=4, Gate_Num=2000, P_T=0.08,seed=1000,time=0.07815909385681152
# done. Qubits=4, Gate_Num=2000, P_T=0.12,seed=1000,time=0.10186958312988281
# done. Qubits=4, Gate_Num=2000, P_T=0.16,seed=1000,time=0.08145880699157715
# done. Qubits=4, Gate_Num=2000, P_T=0.2,seed=1000,time=0.06853318214416504
# done. Qubits=4, Gate_Num=2000, P_T=0.24,seed=1000,time=0.07942056655883789
# done. Qubits=4, Gate_Num=2000, P_T=0.28,seed=1000,time=0.09871888160705566
# done. Qubits=4, Gate_Num=2000, P_T=0.32,seed=1000,time=0.06915473937988281
# done. Qubits=4, Gate_Num=2000, P_T=0.36,seed=1000,time=0.07654714584350586
# done. Qubits=4, Gate_Num=2000, P_T=0.4,seed=1000,time=0.07544302940368652
# done. Qubits=4, Gate_Num=5000, P_T=0.0,seed=1000,time=0.4223630428314209
# done. Qubits=4, Gate_Num=5000, P_T=0.04,seed=1000,time=0.33139634132385254
# done. Qubits=4, Gate_Num=5000, P_T=0.08,seed=1000,time=0.2877345085144043
# done. Qubits=4, Gate_Num=5000, P_T=0.12,seed=1000,time=0.33273911476135254
# done. Qubits=4, Gate_Num=5000, P_T=0.16,seed=1000,time=0.36190223693847656
# done. Qubits=4, Gate_Num=5000, P_T=0.2,seed=1000,time=0.30049729347229004
# done. Qubits=4, Gate_Num=5000, P_T=0.24,seed=1000,time=0.34101176261901855
# done. Qubits=4, Gate_Num=5000, P_T=0.28,seed=1000,time=0.343275785446167
# done. Qubits=4, Gate_Num=5000, P_T=0.32,seed=1000,time=0.35924625396728516
# done. Qubits=4, Gate_Num=5000, P_T=0.36,seed=1000,time=0.3219900131225586
# done. Qubits=4, Gate_Num=5000, P_T=0.4,seed=1000,time=0.3259613513946533
# done. Qubits=4, Gate_Num=10000, P_T=0.0,seed=1000,time=1.1260631084442139
# done. Qubits=4, Gate_Num=10000, P_T=0.04,seed=1000,time=1.0047917366027832
# done. Qubits=4, Gate_Num=10000, P_T=0.08,seed=1000,time=1.1596455574035645
# done. Qubits=4, Gate_Num=10000, P_T=0.12,seed=1000,time=1.1659882068634033
# done. Qubits=4, Gate_Num=10000, P_T=0.16,seed=1000,time=1.1615362167358398
# done. Qubits=4, Gate_Num=10000, P_T=0.2,seed=1000,time=1.0192773342132568
# done. Qubits=4, Gate_Num=10000, P_T=0.24,seed=1000,time=1.2498903274536133
# done. Qubits=4, Gate_Num=10000, P_T=0.28,seed=1000,time=1.162003517150879
# done. Qubits=4, Gate_Num=10000, P_T=0.32,seed=1000,time=1.1857454776763916
# done. Qubits=4, Gate_Num=10000, P_T=0.36,seed=1000,time=1.1592199802398682
# done. Qubits=4, Gate_Num=10000, P_T=0.4,seed=1000,time=1.1480460166931152
# done. Qubits=4, Gate_Num=50000, P_T=0.0,seed=1000,time=27.079023122787476
# done. Qubits=4, Gate_Num=50000, P_T=0.04,seed=1000,time=26.413738489151
# done. Qubits=4, Gate_Num=50000, P_T=0.08,seed=1000,time=24.241138458251953
# done. Qubits=4, Gate_Num=50000, P_T=0.12,seed=1000,time=27.387702703475952
# done. Qubits=4, Gate_Num=50000, P_T=0.16,seed=1000,time=31.49517846107483
# done. Qubits=4, Gate_Num=50000, P_T=0.2,seed=1000,time=29.99904465675354
# done. Qubits=4, Gate_Num=50000, P_T=0.24,seed=1000,time=26.568175554275513
# done. Qubits=4, Gate_Num=50000, P_T=0.28,seed=1000,time=32.462655544281006
# done. Qubits=4, Gate_Num=50000, P_T=0.32,seed=1000,time=32.277060747146606
# done. Qubits=4, Gate_Num=50000, P_T=0.36,seed=1000,time=28.18946671485901
# done. Qubits=4, Gate_Num=50000, P_T=0.4,seed=1000,time=28.60899806022644
# done. Qubits=4, Gate_Num=100000, P_T=0.0,seed=1000,time=120.03423404693604
# done. Qubits=4, Gate_Num=100000, P_T=0.04,seed=1000,time=135.09127569198608
# done. Qubits=4, Gate_Num=100000, P_T=0.08,seed=1000,time=144.3946213722229
# done. Qubits=4, Gate_Num=100000, P_T=0.12,seed=1000,time=146.01592636108398
# done. Qubits=4, Gate_Num=100000, P_T=0.16,seed=1000,time=113.4904408454895
# done. Qubits=4, Gate_Num=100000, P_T=0.2,seed=1000,time=143.8569939136505
# done. Qubits=4, Gate_Num=100000, P_T=0.24,seed=1000,time=128.54415583610535
# done. Qubits=4, Gate_Num=100000, P_T=0.28,seed=1000,time=107.86040496826172
# done. Qubits=4, Gate_Num=100000, P_T=0.32,seed=1000,time=121.38312339782715
# done. Qubits=4, Gate_Num=100000, P_T=0.36,seed=1000,time=109.50125980377197
# done. Qubits=4, Gate_Num=100000, P_T=0.4,seed=1000,time=104.90177869796753
# done. Qubits=8, Gate_Num=100, P_T=0.0,seed=1000,time=0.0064580440521240234
# done. Qubits=8, Gate_Num=100, P_T=0.04,seed=1000,time=0.003120899200439453
# done. Qubits=8, Gate_Num=100, P_T=0.08,seed=1000,time=0.002850055694580078
# done. Qubits=8, Gate_Num=100, P_T=0.12,seed=1000,time=0.0027849674224853516
# done. Qubits=8, Gate_Num=100, P_T=0.16,seed=1000,time=0.0030934810638427734
# done. Qubits=8, Gate_Num=100, P_T=0.2,seed=1000,time=0.003287792205810547
# done. Qubits=8, Gate_Num=100, P_T=0.24,seed=1000,time=0.0031838417053222656
# done. Qubits=8, Gate_Num=100, P_T=0.28,seed=1000,time=0.002952098846435547
# done. Qubits=8, Gate_Num=100, P_T=0.32,seed=1000,time=0.0029494762420654297
# done. Qubits=8, Gate_Num=100, P_T=0.36,seed=1000,time=0.0025997161865234375
# done. Qubits=8, Gate_Num=100, P_T=0.4,seed=1000,time=0.0028274059295654297
# done. Qubits=8, Gate_Num=500, P_T=0.0,seed=1000,time=0.014386177062988281
# done. Qubits=8, Gate_Num=500, P_T=0.04,seed=1000,time=0.01428675651550293
# done. Qubits=8, Gate_Num=500, P_T=0.08,seed=1000,time=0.013925313949584961
# done. Qubits=8, Gate_Num=500, P_T=0.12,seed=1000,time=0.012971162796020508
# done. Qubits=8, Gate_Num=500, P_T=0.16,seed=1000,time=0.0138397216796875
# done. Qubits=8, Gate_Num=500, P_T=0.2,seed=1000,time=0.013811111450195312
# done. Qubits=8, Gate_Num=500, P_T=0.24,seed=1000,time=0.013712882995605469
# done. Qubits=8, Gate_Num=500, P_T=0.28,seed=1000,time=0.011981487274169922
# done. Qubits=8, Gate_Num=500, P_T=0.32,seed=1000,time=0.012438535690307617
# done. Qubits=8, Gate_Num=500, P_T=0.36,seed=1000,time=0.011871814727783203
# done. Qubits=8, Gate_Num=500, P_T=0.4,seed=1000,time=0.012311697006225586
# done. Qubits=8, Gate_Num=1000, P_T=0.0,seed=1000,time=0.03508877754211426
# done. Qubits=8, Gate_Num=1000, P_T=0.04,seed=1000,time=0.029267549514770508
# done. Qubits=8, Gate_Num=1000, P_T=0.08,seed=1000,time=0.025915861129760742
# done. Qubits=8, Gate_Num=1000, P_T=0.12,seed=1000,time=0.026495933532714844
# done. Qubits=8, Gate_Num=1000, P_T=0.16,seed=1000,time=0.02698659896850586
# done. Qubits=8, Gate_Num=1000, P_T=0.2,seed=1000,time=0.0356748104095459
# done. Qubits=8, Gate_Num=1000, P_T=0.24,seed=1000,time=0.028417110443115234
# done. Qubits=8, Gate_Num=1000, P_T=0.28,seed=1000,time=0.030057668685913086
# done. Qubits=8, Gate_Num=1000, P_T=0.32,seed=1000,time=0.06576895713806152
# done. Qubits=8, Gate_Num=1000, P_T=0.36,seed=1000,time=0.025201082229614258
# done. Qubits=8, Gate_Num=1000, P_T=0.4,seed=1000,time=0.02481698989868164
# done. Qubits=8, Gate_Num=2000, P_T=0.0,seed=1000,time=0.06580114364624023
# done. Qubits=8, Gate_Num=2000, P_T=0.04,seed=1000,time=0.07878732681274414
# done. Qubits=8, Gate_Num=2000, P_T=0.08,seed=1000,time=0.057445526123046875
# done. Qubits=8, Gate_Num=2000, P_T=0.12,seed=1000,time=0.07324910163879395
# done. Qubits=8, Gate_Num=2000, P_T=0.16,seed=1000,time=0.09074783325195312
# done. Qubits=8, Gate_Num=2000, P_T=0.2,seed=1000,time=0.06678271293640137
# done. Qubits=8, Gate_Num=2000, P_T=0.24,seed=1000,time=0.058645009994506836
# done. Qubits=8, Gate_Num=2000, P_T=0.28,seed=1000,time=0.07849335670471191
# done. Qubits=8, Gate_Num=2000, P_T=0.32,seed=1000,time=0.055071115493774414
# done. Qubits=8, Gate_Num=2000, P_T=0.36,seed=1000,time=0.05443263053894043
# done. Qubits=8, Gate_Num=2000, P_T=0.4,seed=1000,time=0.05334758758544922
# done. Qubits=8, Gate_Num=5000, P_T=0.0,seed=1000,time=0.22087621688842773
# done. Qubits=8, Gate_Num=5000, P_T=0.04,seed=1000,time=0.24390077590942383
# done. Qubits=8, Gate_Num=5000, P_T=0.08,seed=1000,time=0.2669999599456787
# done. Qubits=8, Gate_Num=5000, P_T=0.12,seed=1000,time=0.24960827827453613
# done. Qubits=8, Gate_Num=5000, P_T=0.16,seed=1000,time=0.2537379264831543
# done. Qubits=8, Gate_Num=5000, P_T=0.2,seed=1000,time=0.24985122680664062
# done. Qubits=8, Gate_Num=5000, P_T=0.24,seed=1000,time=0.18857574462890625
# done. Qubits=8, Gate_Num=5000, P_T=0.28,seed=1000,time=0.22717905044555664
# done. Qubits=8, Gate_Num=5000, P_T=0.32,seed=1000,time=0.23710370063781738
# done. Qubits=8, Gate_Num=5000, P_T=0.36,seed=1000,time=0.18321990966796875
# done. Qubits=8, Gate_Num=5000, P_T=0.4,seed=1000,time=0.2103416919708252
# done. Qubits=8, Gate_Num=10000, P_T=0.0,seed=1000,time=0.6500298976898193
# done. Qubits=8, Gate_Num=10000, P_T=0.04,seed=1000,time=0.6619470119476318
# done. Qubits=8, Gate_Num=10000, P_T=0.08,seed=1000,time=0.6352739334106445
# done. Qubits=8, Gate_Num=10000, P_T=0.12,seed=1000,time=0.6506562232971191
# done. Qubits=8, Gate_Num=10000, P_T=0.16,seed=1000,time=0.6475207805633545
# done. Qubits=8, Gate_Num=10000, P_T=0.2,seed=1000,time=0.7561562061309814
# done. Qubits=8, Gate_Num=10000, P_T=0.24,seed=1000,time=0.6559267044067383
# done. Qubits=8, Gate_Num=10000, P_T=0.28,seed=1000,time=0.6785883903503418
# done. Qubits=8, Gate_Num=10000, P_T=0.32,seed=1000,time=0.5969789028167725
# done. Qubits=8, Gate_Num=10000, P_T=0.36,seed=1000,time=0.5842554569244385
# done. Qubits=8, Gate_Num=10000, P_T=0.4,seed=1000,time=0.6360466480255127
# done. Qubits=8, Gate_Num=50000, P_T=0.0,seed=1000,time=15.708534717559814
# done. Qubits=8, Gate_Num=50000, P_T=0.04,seed=1000,time=13.405617952346802
# done. Qubits=8, Gate_Num=50000, P_T=0.08,seed=1000,time=11.385284185409546
# done. Qubits=8, Gate_Num=50000, P_T=0.12,seed=1000,time=15.236226081848145
# done. Qubits=8, Gate_Num=50000, P_T=0.16,seed=1000,time=17.001678705215454
# done. Qubits=8, Gate_Num=50000, P_T=0.2,seed=1000,time=15.477376222610474
# done. Qubits=8, Gate_Num=50000, P_T=0.24,seed=1000,time=14.742114305496216
# done. Qubits=8, Gate_Num=50000, P_T=0.28,seed=1000,time=12.18411135673523
# done. Qubits=8, Gate_Num=50000, P_T=0.32,seed=1000,time=11.775753498077393
# done. Qubits=8, Gate_Num=50000, P_T=0.36,seed=1000,time=12.575221538543701
# done. Qubits=8, Gate_Num=50000, P_T=0.4,seed=1000,time=12.37375783920288
# done. Qubits=8, Gate_Num=100000, P_T=0.0,seed=1000,time=71.32877111434937
# done. Qubits=8, Gate_Num=100000, P_T=0.04,seed=1000,time=60.32513403892517
# done. Qubits=8, Gate_Num=100000, P_T=0.08,seed=1000,time=67.77678370475769
# done. Qubits=8, Gate_Num=100000, P_T=0.12,seed=1000,time=67.55788493156433
# done. Qubits=8, Gate_Num=100000, P_T=0.16,seed=1000,time=83.92267417907715
# done. Qubits=8, Gate_Num=100000, P_T=0.2,seed=1000,time=66.22191452980042
# done. Qubits=8, Gate_Num=100000, P_T=0.24,seed=1000,time=59.40766453742981
# done. Qubits=8, Gate_Num=100000, P_T=0.28,seed=1000,time=58.677494287490845
# done. Qubits=8, Gate_Num=100000, P_T=0.32,seed=1000,time=61.09489393234253
# done. Qubits=8, Gate_Num=100000, P_T=0.36,seed=1000,time=61.45486783981323
# done. Qubits=8, Gate_Num=100000, P_T=0.4,seed=1000,time=54.39280366897583
# done. Qubits=12, Gate_Num=100, P_T=0.0,seed=1000,time=0.0055005550384521484
# done. Qubits=12, Gate_Num=100, P_T=0.04,seed=1000,time=0.0017294883728027344
# done. Qubits=12, Gate_Num=100, P_T=0.08,seed=1000,time=0.0017702579498291016
# done. Qubits=12, Gate_Num=100, P_T=0.12,seed=1000,time=0.0017843246459960938
# done. Qubits=12, Gate_Num=100, P_T=0.16,seed=1000,time=0.0023589134216308594
# done. Qubits=12, Gate_Num=100, P_T=0.2,seed=1000,time=0.0016722679138183594
# done. Qubits=12, Gate_Num=100, P_T=0.24,seed=1000,time=0.0020492076873779297
# done. Qubits=12, Gate_Num=100, P_T=0.28,seed=1000,time=0.00179290771484375
# done. Qubits=12, Gate_Num=100, P_T=0.32,seed=1000,time=0.0016255378723144531
# done. Qubits=12, Gate_Num=100, P_T=0.36,seed=1000,time=0.0019690990447998047
# done. Qubits=12, Gate_Num=100, P_T=0.4,seed=1000,time=0.002032756805419922
# done. Qubits=12, Gate_Num=500, P_T=0.0,seed=1000,time=0.013011455535888672
# done. Qubits=12, Gate_Num=500, P_T=0.04,seed=1000,time=0.01560664176940918
# done. Qubits=12, Gate_Num=500, P_T=0.08,seed=1000,time=0.011147737503051758
# done. Qubits=12, Gate_Num=500, P_T=0.12,seed=1000,time=0.012755393981933594
# done. Qubits=12, Gate_Num=500, P_T=0.16,seed=1000,time=0.014536619186401367
# done. Qubits=12, Gate_Num=500, P_T=0.2,seed=1000,time=0.014487743377685547
# done. Qubits=12, Gate_Num=500, P_T=0.24,seed=1000,time=0.011246681213378906
# done. Qubits=12, Gate_Num=500, P_T=0.28,seed=1000,time=0.01420903205871582
# done. Qubits=12, Gate_Num=500, P_T=0.32,seed=1000,time=0.01002645492553711
# done. Qubits=12, Gate_Num=500, P_T=0.36,seed=1000,time=0.00970149040222168
# done. Qubits=12, Gate_Num=500, P_T=0.4,seed=1000,time=0.009354114532470703
# done. Qubits=12, Gate_Num=1000, P_T=0.0,seed=1000,time=0.03243112564086914
# done. Qubits=12, Gate_Num=1000, P_T=0.04,seed=1000,time=0.032027482986450195
# done. Qubits=12, Gate_Num=1000, P_T=0.08,seed=1000,time=0.030804157257080078
# done. Qubits=12, Gate_Num=1000, P_T=0.12,seed=1000,time=0.0256345272064209
# done. Qubits=12, Gate_Num=1000, P_T=0.16,seed=1000,time=0.03234124183654785
# done. Qubits=12, Gate_Num=1000, P_T=0.2,seed=1000,time=0.028128385543823242
# done. Qubits=12, Gate_Num=1000, P_T=0.24,seed=1000,time=0.07458686828613281
# done. Qubits=12, Gate_Num=1000, P_T=0.28,seed=1000,time=0.030007123947143555
# done. Qubits=12, Gate_Num=1000, P_T=0.32,seed=1000,time=0.026083946228027344
# done. Qubits=12, Gate_Num=1000, P_T=0.36,seed=1000,time=0.020560264587402344
# done. Qubits=12, Gate_Num=1000, P_T=0.4,seed=1000,time=0.020035266876220703
# done. Qubits=12, Gate_Num=2000, P_T=0.0,seed=1000,time=0.0691535472869873
# done. Qubits=12, Gate_Num=2000, P_T=0.04,seed=1000,time=0.06277298927307129
# done. Qubits=12, Gate_Num=2000, P_T=0.08,seed=1000,time=0.07755112648010254
# done. Qubits=12, Gate_Num=2000, P_T=0.12,seed=1000,time=0.08327794075012207
# done. Qubits=12, Gate_Num=2000, P_T=0.16,seed=1000,time=0.061559438705444336
# done. Qubits=12, Gate_Num=2000, P_T=0.2,seed=1000,time=0.05932259559631348
# done. Qubits=12, Gate_Num=2000, P_T=0.24,seed=1000,time=0.05620002746582031
# done. Qubits=12, Gate_Num=2000, P_T=0.28,seed=1000,time=0.07872223854064941
# done. Qubits=12, Gate_Num=2000, P_T=0.32,seed=1000,time=0.05486941337585449
# done. Qubits=12, Gate_Num=2000, P_T=0.36,seed=1000,time=0.044553279876708984
# done. Qubits=12, Gate_Num=2000, P_T=0.4,seed=1000,time=0.045196533203125
# done. Qubits=12, Gate_Num=5000, P_T=0.0,seed=1000,time=0.21910405158996582
# done. Qubits=12, Gate_Num=5000, P_T=0.04,seed=1000,time=0.22996902465820312
# done. Qubits=12, Gate_Num=5000, P_T=0.08,seed=1000,time=0.2675602436065674
# done. Qubits=12, Gate_Num=5000, P_T=0.12,seed=1000,time=0.22562885284423828
# done. Qubits=12, Gate_Num=5000, P_T=0.16,seed=1000,time=0.2771587371826172
# done. Qubits=12, Gate_Num=5000, P_T=0.2,seed=1000,time=0.1945507526397705
# done. Qubits=12, Gate_Num=5000, P_T=0.24,seed=1000,time=0.16878962516784668
# done. Qubits=12, Gate_Num=5000, P_T=0.28,seed=1000,time=0.21694707870483398
# done. Qubits=12, Gate_Num=5000, P_T=0.32,seed=1000,time=0.19109535217285156
# done. Qubits=12, Gate_Num=5000, P_T=0.36,seed=1000,time=0.16489768028259277
# done. Qubits=12, Gate_Num=5000, P_T=0.4,seed=1000,time=0.18565678596496582
# done. Qubits=12, Gate_Num=10000, P_T=0.0,seed=1000,time=0.5686085224151611
# done. Qubits=12, Gate_Num=10000, P_T=0.04,seed=1000,time=0.5356996059417725
# done. Qubits=12, Gate_Num=10000, P_T=0.08,seed=1000,time=0.6762852668762207
# done. Qubits=12, Gate_Num=10000, P_T=0.12,seed=1000,time=0.6550905704498291
# done. Qubits=12, Gate_Num=10000, P_T=0.16,seed=1000,time=0.6526792049407959
# done. Qubits=12, Gate_Num=10000, P_T=0.2,seed=1000,time=0.48826122283935547
# done. Qubits=12, Gate_Num=10000, P_T=0.24,seed=1000,time=0.6790151596069336
# done. Qubits=12, Gate_Num=10000, P_T=0.28,seed=1000,time=0.6718659400939941
# done. Qubits=12, Gate_Num=10000, P_T=0.32,seed=1000,time=0.5405466556549072
# done. Qubits=12, Gate_Num=10000, P_T=0.36,seed=1000,time=0.48664093017578125
# done. Qubits=12, Gate_Num=10000, P_T=0.4,seed=1000,time=0.489504337310791
# done. Qubits=12, Gate_Num=50000, P_T=0.0,seed=1000,time=8.330549716949463
# done. Qubits=12, Gate_Num=50000, P_T=0.04,seed=1000,time=12.904427528381348
# done. Qubits=12, Gate_Num=50000, P_T=0.08,seed=1000,time=10.705201387405396
# done. Qubits=12, Gate_Num=50000, P_T=0.12,seed=1000,time=8.928774118423462
# done. Qubits=12, Gate_Num=50000, P_T=0.16,seed=1000,time=10.07226300239563
# done. Qubits=12, Gate_Num=50000, P_T=0.2,seed=1000,time=10.21068263053894
# done. Qubits=12, Gate_Num=50000, P_T=0.24,seed=1000,time=10.10576868057251
# done. Qubits=12, Gate_Num=50000, P_T=0.28,seed=1000,time=9.775165319442749
# done. Qubits=12, Gate_Num=50000, P_T=0.32,seed=1000,time=9.678171396255493
# done. Qubits=12, Gate_Num=50000, P_T=0.36,seed=1000,time=8.850382566452026
# done. Qubits=12, Gate_Num=50000, P_T=0.4,seed=1000,time=9.635800123214722
# done. Qubits=12, Gate_Num=100000, P_T=0.0,seed=1000,time=49.678858518600464
# done. Qubits=12, Gate_Num=100000, P_T=0.04,seed=1000,time=49.6001353263855
# done. Qubits=12, Gate_Num=100000, P_T=0.08,seed=1000,time=61.24948978424072
# done. Qubits=12, Gate_Num=100000, P_T=0.12,seed=1000,time=53.89555072784424
# done. Qubits=12, Gate_Num=100000, P_T=0.16,seed=1000,time=38.12947416305542
# done. Qubits=12, Gate_Num=100000, P_T=0.2,seed=1000,time=44.26058864593506
# done. Qubits=12, Gate_Num=100000, P_T=0.24,seed=1000,time=46.7326762676239
# done. Qubits=12, Gate_Num=100000, P_T=0.28,seed=1000,time=43.87742471694946
# done. Qubits=12, Gate_Num=100000, P_T=0.32,seed=1000,time=44.76034116744995
# done. Qubits=12, Gate_Num=100000, P_T=0.36,seed=1000,time=41.3145112991333
# done. Qubits=12, Gate_Num=100000, P_T=0.4,seed=1000,time=43.38651442527771
# done. Qubits=16, Gate_Num=100, P_T=0.0,seed=1000,time=0.0074651241302490234
# done. Qubits=16, Gate_Num=100, P_T=0.04,seed=1000,time=0.002988100051879883
# done. Qubits=16, Gate_Num=100, P_T=0.08,seed=1000,time=0.002132415771484375
# done. Qubits=16, Gate_Num=100, P_T=0.12,seed=1000,time=0.001978158950805664
# done. Qubits=16, Gate_Num=100, P_T=0.16,seed=1000,time=0.0027527809143066406
# done. Qubits=16, Gate_Num=100, P_T=0.2,seed=1000,time=0.0019347667694091797
# done. Qubits=16, Gate_Num=100, P_T=0.24,seed=1000,time=0.0020208358764648438
# done. Qubits=16, Gate_Num=100, P_T=0.28,seed=1000,time=0.001958608627319336
# done. Qubits=16, Gate_Num=100, P_T=0.32,seed=1000,time=0.001882791519165039
# done. Qubits=16, Gate_Num=100, P_T=0.36,seed=1000,time=0.0024590492248535156
# done. Qubits=16, Gate_Num=100, P_T=0.4,seed=1000,time=0.0019800662994384766
# done. Qubits=16, Gate_Num=500, P_T=0.0,seed=1000,time=0.021203994750976562
# done. Qubits=16, Gate_Num=500, P_T=0.04,seed=1000,time=0.017996788024902344
# done. Qubits=16, Gate_Num=500, P_T=0.08,seed=1000,time=0.013916492462158203
# done. Qubits=16, Gate_Num=500, P_T=0.12,seed=1000,time=0.017430543899536133
# done. Qubits=16, Gate_Num=500, P_T=0.16,seed=1000,time=0.01596522331237793
# done. Qubits=16, Gate_Num=500, P_T=0.2,seed=1000,time=0.012129068374633789
# done. Qubits=16, Gate_Num=500, P_T=0.24,seed=1000,time=0.012262344360351562
# done. Qubits=16, Gate_Num=500, P_T=0.28,seed=1000,time=0.015552520751953125
# done. Qubits=16, Gate_Num=500, P_T=0.32,seed=1000,time=0.011631965637207031
# done. Qubits=16, Gate_Num=500, P_T=0.36,seed=1000,time=0.011429786682128906
# done. Qubits=16, Gate_Num=500, P_T=0.4,seed=1000,time=0.014531135559082031
# done. Qubits=16, Gate_Num=1000, P_T=0.0,seed=1000,time=0.07644104957580566
# done. Qubits=16, Gate_Num=1000, P_T=0.04,seed=1000,time=0.03381514549255371
# done. Qubits=16, Gate_Num=1000, P_T=0.08,seed=1000,time=0.0350947380065918
# done. Qubits=16, Gate_Num=1000, P_T=0.12,seed=1000,time=0.04114532470703125
# done. Qubits=16, Gate_Num=1000, P_T=0.16,seed=1000,time=0.03477597236633301
# done. Qubits=16, Gate_Num=1000, P_T=0.2,seed=1000,time=0.031159400939941406
# done. Qubits=16, Gate_Num=1000, P_T=0.24,seed=1000,time=0.028937578201293945
# done. Qubits=16, Gate_Num=1000, P_T=0.28,seed=1000,time=0.029329776763916016
# done. Qubits=16, Gate_Num=1000, P_T=0.32,seed=1000,time=0.02332758903503418
# done. Qubits=16, Gate_Num=1000, P_T=0.36,seed=1000,time=0.023194313049316406
# done. Qubits=16, Gate_Num=1000, P_T=0.4,seed=1000,time=0.02767205238342285
# done. Qubits=16, Gate_Num=2000, P_T=0.0,seed=1000,time=0.0666654109954834
# done. Qubits=16, Gate_Num=2000, P_T=0.04,seed=1000,time=0.09349989891052246
# done. Qubits=16, Gate_Num=2000, P_T=0.08,seed=1000,time=0.06594157218933105
# done. Qubits=16, Gate_Num=2000, P_T=0.12,seed=1000,time=0.06726408004760742
# done. Qubits=16, Gate_Num=2000, P_T=0.16,seed=1000,time=0.06883978843688965
# done. Qubits=16, Gate_Num=2000, P_T=0.2,seed=1000,time=0.09189486503601074
# done. Qubits=16, Gate_Num=2000, P_T=0.24,seed=1000,time=0.0626840591430664
# done. Qubits=16, Gate_Num=2000, P_T=0.28,seed=1000,time=0.06112551689147949
# done. Qubits=16, Gate_Num=2000, P_T=0.32,seed=1000,time=0.04964399337768555
# done. Qubits=16, Gate_Num=2000, P_T=0.36,seed=1000,time=0.04937410354614258
# done. Qubits=16, Gate_Num=2000, P_T=0.4,seed=1000,time=0.054219722747802734
# done. Qubits=16, Gate_Num=5000, P_T=0.0,seed=1000,time=0.2423079013824463
# done. Qubits=16, Gate_Num=5000, P_T=0.04,seed=1000,time=0.2662227153778076
# done. Qubits=16, Gate_Num=5000, P_T=0.08,seed=1000,time=0.2182607650756836
# done. Qubits=16, Gate_Num=5000, P_T=0.12,seed=1000,time=0.22246432304382324
# done. Qubits=16, Gate_Num=5000, P_T=0.16,seed=1000,time=0.20513200759887695
# done. Qubits=16, Gate_Num=5000, P_T=0.2,seed=1000,time=0.19820761680603027
# done. Qubits=16, Gate_Num=5000, P_T=0.24,seed=1000,time=0.2549924850463867
# done. Qubits=16, Gate_Num=5000, P_T=0.28,seed=1000,time=0.1749260425567627
# done. Qubits=16, Gate_Num=5000, P_T=0.32,seed=1000,time=0.19788241386413574
# done. Qubits=16, Gate_Num=5000, P_T=0.36,seed=1000,time=0.19098591804504395
# done. Qubits=16, Gate_Num=5000, P_T=0.4,seed=1000,time=0.16239452362060547
# done. Qubits=16, Gate_Num=10000, P_T=0.0,seed=1000,time=0.5899224281311035
# done. Qubits=16, Gate_Num=10000, P_T=0.04,seed=1000,time=0.513005256652832
# done. Qubits=16, Gate_Num=10000, P_T=0.08,seed=1000,time=0.6908555030822754
# done. Qubits=16, Gate_Num=10000, P_T=0.12,seed=1000,time=0.5649561882019043
# done. Qubits=16, Gate_Num=10000, P_T=0.16,seed=1000,time=0.536142110824585
# done. Qubits=16, Gate_Num=10000, P_T=0.2,seed=1000,time=0.6244456768035889
# done. Qubits=16, Gate_Num=10000, P_T=0.24,seed=1000,time=0.4689161777496338
# done. Qubits=16, Gate_Num=10000, P_T=0.28,seed=1000,time=0.4947953224182129
# done. Qubits=16, Gate_Num=10000, P_T=0.32,seed=1000,time=0.5272243022918701
# done. Qubits=16, Gate_Num=10000, P_T=0.36,seed=1000,time=0.49418067932128906
# done. Qubits=16, Gate_Num=10000, P_T=0.4,seed=1000,time=0.46286702156066895
# done. Qubits=16, Gate_Num=50000, P_T=0.0,seed=1000,time=6.125630140304565
# done. Qubits=16, Gate_Num=50000, P_T=0.04,seed=1000,time=6.440844297409058
# done. Qubits=16, Gate_Num=50000, P_T=0.08,seed=1000,time=8.680563688278198
# done. Qubits=16, Gate_Num=50000, P_T=0.12,seed=1000,time=6.985555171966553
# done. Qubits=16, Gate_Num=50000, P_T=0.16,seed=1000,time=7.971805810928345
# done. Qubits=16, Gate_Num=50000, P_T=0.2,seed=1000,time=7.709871292114258
# done. Qubits=16, Gate_Num=50000, P_T=0.24,seed=1000,time=7.482638597488403
# done. Qubits=16, Gate_Num=50000, P_T=0.28,seed=1000,time=7.155726432800293
# done. Qubits=16, Gate_Num=50000, P_T=0.32,seed=1000,time=7.971746206283569
# done. Qubits=16, Gate_Num=50000, P_T=0.36,seed=1000,time=7.378551721572876
# done. Qubits=16, Gate_Num=50000, P_T=0.4,seed=1000,time=7.272111654281616
# done. Qubits=16, Gate_Num=100000, P_T=0.0,seed=1000,time=32.15685057640076
# done. Qubits=16, Gate_Num=100000, P_T=0.04,seed=1000,time=28.099567651748657
# done. Qubits=16, Gate_Num=100000, P_T=0.08,seed=1000,time=32.22640013694763
# done. Qubits=16, Gate_Num=100000, P_T=0.12,seed=1000,time=31.688215732574463
# done. Qubits=16, Gate_Num=100000, P_T=0.16,seed=1000,time=29.73275065422058
# done. Qubits=16, Gate_Num=100000, P_T=0.2,seed=1000,time=27.71373701095581
# done. Qubits=16, Gate_Num=100000, P_T=0.24,seed=1000,time=33.18316316604614
# done. Qubits=16, Gate_Num=100000, P_T=0.28,seed=1000,time=29.3401198387146
# done. Qubits=16, Gate_Num=100000, P_T=0.32,seed=1000,time=27.43873882293701
# done. Qubits=16, Gate_Num=100000, P_T=0.36,seed=1000,time=29.997515201568604
# done. Qubits=16, Gate_Num=100000, P_T=0.4,seed=1000,time=28.507869243621826
# Total time: 3663.5292658805847
