# %%
import pyzx as zx
import random
from qiskit import QuantumCircuit
from qiskit.circuit import QuantumCircuit, ParameterVector
import csv
import time

# %%
def generate_H_S_CNOT_T_circuit(qubits, gates, p_t=0, seed=1000):
    random.seed(seed)  
    p_s = 0.333 * (1.0 - p_t)  
    p_had = 0.333 * (1.0 - p_t)  
    p_cnot = 0.333 * (1.0 - p_t)  

    c = zx.Circuit(qubits) 
    for _ in range(gates):
        r = random.random() 
        if r < p_had:
            c.add_gate("HAD", random.randrange(qubits))
        elif r < p_had + p_s:
            c.add_gate("S", random.randrange(qubits))
        elif r < p_had + p_s + p_t:
            c.add_gate("T", random.randrange(qubits))
        else:
            tgt = random.randrange(qubits)
            while True:
                ctrl = random.randrange(qubits)
                if ctrl != tgt:
                    break
            c.add_gate("CNOT", tgt, ctrl)
    return c

# %%
# seed固定
seed = 1000
random.seed(seed)

# パラメータ設定
qubits_list = [4, 8, 12, 16]
p_t_lists = [i * 0.04 for i in range(0, 11)]
gate_num_lists = [100, 500, 1000, 2000, 5000, 10000, 50000]

# CSV書き込みの準備
output_file = "../kekka/1211original_extract.csv"
fieldnames = [
    "optimize_name","data_name","gates","depth","t","H","otherRZ","CNOT","CZ","time"
]
start_all = time.time()
with open(output_file, "w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()



    for qubit in qubits_list:
        for gate_num in gate_num_lists:
            for p_t in p_t_lists:
                try:
                    start = time.time()
                    # 回路作成
                    c = generate_H_S_CNOT_T_circuit(qubits = qubit,gates= gate_num,p_t = p_t,seed = seed)
                    g = c.to_graph()
                    #最適化　この場合はなし

                    #抽出
                    c = zx.extract.streaming_extract(g)
                    

                    end = time.time()

                    #qiskit変換とカウント
                    circuit_qiskit = QuantumCircuit.from_qasm_str(c.to_basic_gates().to_qasm())
                    depth = circuit_qiskit.depth()
                    zx_dict = c.to_basic_gates().stats_dict()
                    qiskit_dict = circuit_qiskit.count_ops()

                    optimize_name = "original"
                    dataname = "q" + str(qubit) + "_gates" + str(gate_num) + "_pt" +str(p_t)+ "_seeds" + str(seed)
                    gates_aft = zx_dict["gates"]


                    # 結果をCSVに書き込む
                    writer.writerow({
                        "optimize_name": optimize_name,
                        "data_name": dataname,
                        "gates": gates_aft,
                        "depth": depth,
                        "t": zx_dict["tcount"],
                        "H": qiskit_dict.get("h", 0),
                        "otherRZ": gates_aft - qiskit_dict.get("h", 0) - qiskit_dict.get("cx", 0) - qiskit_dict.get("cz", 0) - zx_dict["tcount"],
                        "CNOT": qiskit_dict.get("cx", 0),
                        "CZ": qiskit_dict.get("cz", 0),
                        "time": end - start
                    })

                    print(f"done. Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t},seed={seed},time={end-start}")

                except Exception as e:
                    print(f"Error for Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t}: {e}")

end_all = time.time()
print(f"Total time: {end_all - start_all}")
# Out:
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.0,seed=1000,time=0.007483720779418945
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.04,seed=1000,time=0.002524852752685547
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.08,seed=1000,time=0.002431631088256836
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.12,seed=1000,time=0.0024416446685791016
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.16,seed=1000,time=0.0024614334106445312
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.2,seed=1000,time=0.0025327205657958984
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.24,seed=1000,time=0.002827882766723633
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.28,seed=1000,time=0.0026929378509521484
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.32,seed=1000,time=0.0025870800018310547
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.36,seed=1000,time=0.002557516098022461
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.4,seed=1000,time=0.002676725387573242
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.0,seed=1000,time=0.016148805618286133
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.04,seed=1000,time=0.014040708541870117
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.08,seed=1000,time=0.013429880142211914
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.12,seed=1000,time=0.013738393783569336
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.16,seed=1000,time=0.012955188751220703
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.2,seed=1000,time=0.012954950332641602
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.24,seed=1000,time=0.012915372848510742
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.28,seed=1000,time=0.01248311996459961
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.32,seed=1000,time=0.012679338455200195
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.36,seed=1000,time=0.01174306869506836
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.4,seed=1000,time=0.012149810791015625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.0,seed=1000,time=0.030674219131469727
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.04,seed=1000,time=0.10498952865600586
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.08,seed=1000,time=0.032208919525146484
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.12,seed=1000,time=0.030237913131713867
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.16,seed=1000,time=0.030007600784301758
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.2,seed=1000,time=0.028293609619140625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.24,seed=1000,time=0.02771735191345215
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.28,seed=1000,time=0.03171682357788086
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.32,seed=1000,time=0.027211904525756836
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.36,seed=1000,time=0.027117490768432617
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.4,seed=1000,time=0.02751779556274414
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.0,seed=1000,time=0.07483220100402832
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.04,seed=1000,time=0.0715177059173584
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.08,seed=1000,time=0.11515498161315918
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.12,seed=1000,time=0.07692193984985352
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.16,seed=1000,time=0.07001399993896484
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.2,seed=1000,time=0.06895661354064941
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.24,seed=1000,time=0.1334056854248047
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.28,seed=1000,time=0.0687556266784668
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.32,seed=1000,time=0.06593823432922363
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.36,seed=1000,time=0.06462860107421875
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.4,seed=1000,time=0.10717296600341797
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.0,seed=1000,time=0.27112913131713867
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.04,seed=1000,time=0.3128392696380615
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.08,seed=1000,time=0.27208852767944336
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.12,seed=1000,time=0.2694079875946045
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.16,seed=1000,time=0.31032371520996094
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.2,seed=1000,time=0.25613927841186523
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.24,seed=1000,time=0.2953755855560303
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.28,seed=1000,time=0.3084988594055176
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.32,seed=1000,time=0.24678373336791992
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.36,seed=1000,time=0.2965109348297119
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.4,seed=1000,time=0.2460794448852539
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.0,seed=1000,time=0.9410057067871094
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.04,seed=1000,time=0.9929993152618408
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.08,seed=1000,time=0.9814736843109131
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.12,seed=1000,time=0.9283175468444824
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.16,seed=1000,time=0.9126684665679932
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.2,seed=1000,time=0.8763740062713623
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.24,seed=1000,time=0.8272287845611572
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.28,seed=1000,time=0.8169248104095459
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.32,seed=1000,time=0.8035805225372314
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.36,seed=1000,time=0.7984554767608643
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.4,seed=1000,time=0.7726881504058838
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.0,seed=1000,time=18.87480640411377
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.04,seed=1000,time=17.67586851119995
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.08,seed=1000,time=17.270358562469482
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.12,seed=1000,time=16.879794597625732
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.16,seed=1000,time=16.69828152656555
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.2,seed=1000,time=16.213916778564453
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.24,seed=1000,time=15.96903395652771
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.28,seed=1000,time=15.349514245986938
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.32,seed=1000,time=15.329081058502197
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.36,seed=1000,time=15.3094162940979
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.4,seed=1000,time=14.91562557220459
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.0,seed=1000,time=80.29135394096375
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.04,seed=1000,time=82.71353840827942
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.08,seed=1000,time=79.07863521575928
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.12,seed=1000,time=82.76514339447021
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.16,seed=1000,time=78.58506560325623
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.2,seed=1000,time=72.2854495048523
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.24,seed=1000,time=57.42230701446533
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.28,seed=1000,time=56.359323501586914
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.32,seed=1000,time=58.769861459732056
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.36,seed=1000,time=64.67978310585022
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100000, P_T=0.4,seed=1000,time=63.85641145706177
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.0,seed=1000,time=0.01070094108581543
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.04,seed=1000,time=0.003085613250732422
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.08,seed=1000,time=0.0030019283294677734
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.12,seed=1000,time=0.0033533573150634766
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.16,seed=1000,time=0.003757953643798828
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.2,seed=1000,time=0.0030145645141601562
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.24,seed=1000,time=0.003045797348022461
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.28,seed=1000,time=0.0029296875
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.32,seed=1000,time=0.002939462661743164
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.36,seed=1000,time=0.0033757686614990234
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.4,seed=1000,time=0.002996683120727539
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.0,seed=1000,time=0.017303943634033203
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.04,seed=1000,time=0.017805814743041992
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.08,seed=1000,time=0.016552448272705078
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.12,seed=1000,time=0.016498088836669922
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.16,seed=1000,time=0.015946626663208008
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.2,seed=1000,time=0.016255855560302734
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.24,seed=1000,time=0.01694631576538086
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.28,seed=1000,time=0.02817702293395996
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.32,seed=1000,time=0.03712797164916992
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.36,seed=1000,time=0.017221689224243164
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.4,seed=1000,time=0.017160654067993164
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.0,seed=1000,time=0.040048837661743164
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.04,seed=1000,time=0.03834891319274902
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.08,seed=1000,time=0.03942441940307617
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.12,seed=1000,time=0.03700542449951172
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.16,seed=1000,time=0.03594970703125
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.2,seed=1000,time=0.03680753707885742
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.24,seed=1000,time=0.0355989933013916
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.28,seed=1000,time=0.03401637077331543
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.32,seed=1000,time=0.03384971618652344
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.36,seed=1000,time=0.032349348068237305
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.4,seed=1000,time=0.1448984146118164
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.0,seed=1000,time=0.08682012557983398
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.04,seed=1000,time=0.08646178245544434
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.08,seed=1000,time=0.0832211971282959
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.12,seed=1000,time=0.08649349212646484
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.16,seed=1000,time=0.0859827995300293
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.2,seed=1000,time=0.07766008377075195
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.24,seed=1000,time=0.08142948150634766
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.28,seed=1000,time=0.0796055793762207
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.32,seed=1000,time=0.08158421516418457
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.36,seed=1000,time=0.14145112037658691
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.4,seed=1000,time=0.07775115966796875
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.0,seed=1000,time=0.3623940944671631
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.04,seed=1000,time=0.31199216842651367
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.08,seed=1000,time=0.35227489471435547
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.12,seed=1000,time=0.3143172264099121
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.16,seed=1000,time=0.3543086051940918
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.2,seed=1000,time=0.3636312484741211
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.24,seed=1000,time=0.3095715045928955
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.28,seed=1000,time=0.3507976531982422
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.32,seed=1000,time=0.35903429985046387
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.36,seed=1000,time=0.3129079341888428
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.4,seed=1000,time=0.327838659286499
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.0,seed=1000,time=1.056838035583496
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.04,seed=1000,time=1.0017461776733398
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.08,seed=1000,time=0.9503579139709473
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.12,seed=1000,time=0.923295259475708
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.16,seed=1000,time=0.9077093601226807
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.2,seed=1000,time=0.9355459213256836
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.24,seed=1000,time=0.8975734710693359
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.28,seed=1000,time=0.8661386966705322
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.32,seed=1000,time=0.8442080020904541
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.36,seed=1000,time=0.9306731224060059
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.4,seed=1000,time=0.9120779037475586
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.0,seed=1000,time=19.904892683029175
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.04,seed=1000,time=18.727161645889282
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.08,seed=1000,time=17.976789712905884
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.12,seed=1000,time=17.49165630340576
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.16,seed=1000,time=17.055368661880493
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.2,seed=1000,time=16.91986322402954
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.24,seed=1000,time=16.253843069076538
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.28,seed=1000,time=16.447497129440308
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.32,seed=1000,time=16.117733001708984
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.36,seed=1000,time=15.30054783821106
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.4,seed=1000,time=14.639946937561035
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.0,seed=1000,time=80.72309255599976
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.04,seed=1000,time=91.01215863227844
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.08,seed=1000,time=85.54383063316345
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.12,seed=1000,time=79.93763661384583
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.16,seed=1000,time=80.95703148841858
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.2,seed=1000,time=83.09507942199707
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.24,seed=1000,time=76.90114378929138
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.28,seed=1000,time=73.74889588356018
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.32,seed=1000,time=76.37765955924988
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.36,seed=1000,time=72.51884198188782
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100000, P_T=0.4,seed=1000,time=68.29278945922852
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.0,seed=1000,time=0.012623786926269531
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.04,seed=1000,time=0.004538774490356445
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.08,seed=1000,time=0.004335641860961914
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.12,seed=1000,time=0.0038290023803710938
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.16,seed=1000,time=0.005141258239746094
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.2,seed=1000,time=0.0041429996490478516
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.24,seed=1000,time=0.0041277408599853516
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.28,seed=1000,time=0.004850149154663086
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.32,seed=1000,time=0.004450559616088867
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.36,seed=1000,time=0.0038645267486572266
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.4,seed=1000,time=0.004163503646850586
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.0,seed=1000,time=0.021898508071899414
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.04,seed=1000,time=0.022669076919555664
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.08,seed=1000,time=0.02389216423034668
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.12,seed=1000,time=0.021589994430541992
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.16,seed=1000,time=0.021376371383666992
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.2,seed=1000,time=0.0219879150390625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.24,seed=1000,time=0.02207350730895996
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.28,seed=1000,time=0.02070021629333496
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.32,seed=1000,time=0.01981949806213379
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.36,seed=1000,time=0.020183801651000977
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.4,seed=1000,time=0.021422386169433594
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.0,seed=1000,time=0.049155473709106445
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.04,seed=1000,time=0.04676628112792969
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.08,seed=1000,time=0.04629993438720703
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.12,seed=1000,time=0.04595184326171875
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.16,seed=1000,time=0.045056819915771484
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.2,seed=1000,time=0.04565787315368652
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.24,seed=1000,time=0.0431826114654541
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.28,seed=1000,time=0.04319357872009277
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.32,seed=1000,time=0.04267573356628418
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.36,seed=1000,time=0.04122495651245117
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.4,seed=1000,time=0.04076027870178223
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.0,seed=1000,time=0.10573291778564453
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.04,seed=1000,time=0.2190847396850586
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.08,seed=1000,time=0.10241270065307617
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.12,seed=1000,time=0.10698676109313965
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.16,seed=1000,time=0.09941864013671875
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.2,seed=1000,time=0.09857511520385742
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.24,seed=1000,time=0.09392857551574707
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.28,seed=1000,time=0.09514665603637695
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.32,seed=1000,time=0.09518933296203613
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.36,seed=1000,time=0.08744978904724121
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.4,seed=1000,time=0.14153432846069336
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.0,seed=1000,time=0.35694265365600586
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.04,seed=1000,time=0.3951892852783203
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.08,seed=1000,time=0.4451887607574463
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.12,seed=1000,time=0.3587958812713623
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.16,seed=1000,time=0.3884401321411133
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.2,seed=1000,time=0.32384371757507324
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.24,seed=1000,time=0.38295841217041016
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.28,seed=1000,time=0.3592684268951416
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.32,seed=1000,time=0.308765172958374
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.36,seed=1000,time=0.3481132984161377
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.4,seed=1000,time=0.3497617244720459
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.0,seed=1000,time=1.1057133674621582
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.04,seed=1000,time=1.0968959331512451
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.08,seed=1000,time=1.04854154586792
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.12,seed=1000,time=1.100588321685791
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.16,seed=1000,time=1.0003886222839355
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.2,seed=1000,time=0.9762990474700928
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.24,seed=1000,time=0.9818675518035889
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.28,seed=1000,time=0.9354112148284912
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.32,seed=1000,time=0.9461426734924316
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.36,seed=1000,time=0.9201524257659912
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.4,seed=1000,time=0.9581830501556396
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.0,seed=1000,time=18.729736328125
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.04,seed=1000,time=18.15353298187256
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.08,seed=1000,time=17.58741593360901
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.12,seed=1000,time=17.540294647216797
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.16,seed=1000,time=17.438273668289185
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.2,seed=1000,time=16.59506368637085
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.24,seed=1000,time=16.274531364440918
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.28,seed=1000,time=15.840585708618164
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.32,seed=1000,time=15.839715003967285
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.36,seed=1000,time=15.220085382461548
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.4,seed=1000,time=15.051568984985352
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.0,seed=1000,time=78.51962399482727
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.04,seed=1000,time=82.99694633483887
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.08,seed=1000,time=87.22485518455505
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.12,seed=1000,time=85.88403177261353
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.16,seed=1000,time=81.27173256874084
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.2,seed=1000,time=89.73908758163452
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.24,seed=1000,time=81.92791700363159
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.28,seed=1000,time=83.82981181144714
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.32,seed=1000,time=78.18944311141968
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.36,seed=1000,time=74.4548602104187
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100000, P_T=0.4,seed=1000,time=71.67457938194275
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.0,seed=1000,time=0.02283620834350586
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.04,seed=1000,time=0.0060176849365234375
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.08,seed=1000,time=0.005491733551025391
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.12,seed=1000,time=0.005778312683105469
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.16,seed=1000,time=0.005818843841552734
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.2,seed=1000,time=0.007058143615722656
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.24,seed=1000,time=0.006066322326660156
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.28,seed=1000,time=0.0055065155029296875
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.32,seed=1000,time=0.0052394866943359375
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.36,seed=1000,time=0.005438566207885742
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.4,seed=1000,time=0.004540443420410156
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.0,seed=1000,time=0.03324007987976074
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.04,seed=1000,time=0.033181190490722656
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.08,seed=1000,time=0.03051447868347168
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.12,seed=1000,time=0.029436588287353516
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.16,seed=1000,time=0.030452728271484375
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.2,seed=1000,time=0.031401872634887695
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.24,seed=1000,time=0.03112173080444336
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.28,seed=1000,time=0.027240276336669922
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.32,seed=1000,time=0.026534318923950195
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.36,seed=1000,time=0.025122642517089844
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.4,seed=1000,time=0.026546955108642578
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.0,seed=1000,time=0.07721734046936035
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.04,seed=1000,time=0.06418943405151367
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.08,seed=1000,time=0.06468892097473145
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.12,seed=1000,time=0.06128740310668945
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.16,seed=1000,time=0.16506099700927734
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.2,seed=1000,time=0.059586286544799805
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.24,seed=1000,time=0.060301780700683594
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.28,seed=1000,time=0.05768990516662598
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.32,seed=1000,time=0.0559694766998291
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.36,seed=1000,time=0.0520176887512207
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.4,seed=1000,time=0.049503326416015625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.0,seed=1000,time=0.14217805862426758
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.04,seed=1000,time=0.14227771759033203
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.08,seed=1000,time=0.16185784339904785
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.12,seed=1000,time=0.13545012474060059
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.16,seed=1000,time=0.13204455375671387
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.2,seed=1000,time=0.12918496131896973
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.24,seed=1000,time=0.17741632461547852
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.28,seed=1000,time=0.12562847137451172
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.32,seed=1000,time=0.11507916450500488
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.36,seed=1000,time=0.14739680290222168
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.4,seed=1000,time=0.10754156112670898
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.0,seed=1000,time=0.4603421688079834
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.04,seed=1000,time=0.487093448638916
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.08,seed=1000,time=0.47756290435791016
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.12,seed=1000,time=0.43174147605895996
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.16,seed=1000,time=0.463695764541626
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.2,seed=1000,time=0.4115023612976074
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.24,seed=1000,time=0.4436676502227783
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.28,seed=1000,time=0.4404256343841553
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.32,seed=1000,time=0.37049221992492676
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.36,seed=1000,time=0.44975948333740234
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.4,seed=1000,time=0.43794894218444824
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.0,seed=1000,time=1.286257028579712
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.04,seed=1000,time=1.2993998527526855
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.08,seed=1000,time=1.2808258533477783
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.12,seed=1000,time=1.2667243480682373
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.16,seed=1000,time=1.2642788887023926
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.2,seed=1000,time=1.1899607181549072
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.24,seed=1000,time=1.1895418167114258
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.28,seed=1000,time=1.0953314304351807
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.32,seed=1000,time=1.099865436553955
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.36,seed=1000,time=1.1121790409088135
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.4,seed=1000,time=1.1617629528045654
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.0,seed=1000,time=21.05045247077942
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.04,seed=1000,time=20.32286524772644
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.08,seed=1000,time=20.210789680480957
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.12,seed=1000,time=19.968165636062622
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.16,seed=1000,time=19.562508583068848
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.2,seed=1000,time=18.61303734779358
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.24,seed=1000,time=18.465432167053223
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.28,seed=1000,time=18.687231302261353
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.32,seed=1000,time=17.58583927154541
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.36,seed=1000,time=16.407400131225586
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.4,seed=1000,time=14.531122207641602
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.0,seed=1000,time=80.03596758842468
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.04,seed=1000,time=81.48103642463684
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.08,seed=1000,time=78.58025026321411
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.12,seed=1000,time=80.30238175392151
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.16,seed=1000,time=75.03786659240723
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.2,seed=1000,time=69.74374461174011
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.24,seed=1000,time=69.31581807136536
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.28,seed=1000,time=68.36146855354309
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.32,seed=1000,time=70.48398232460022
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.36,seed=1000,time=66.18427062034607
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100000, P_T=0.4,seed=1000,time=65.85749554634094
# Total time: 4257.869791507721
