# %%
import pyzx as zx
import random
from qiskit import QuantumCircuit
from qiskit.circuit import QuantumCircuit, ParameterVector
import csv
import time

# %%
def generate_H_S_CNOT_T_circuit(qubits, gates, p_t=0, seed=1000):
    random.seed(seed)  
    p_s = 0.333 * (1.0 - p_t)  
    p_had = 0.333 * (1.0 - p_t)  
    p_cnot = 0.333 * (1.0 - p_t)  

    c = zx.Circuit(qubits) 
    for _ in range(gates):
        r = random.random() 
        if r < p_had:
            c.add_gate("HAD", random.randrange(qubits))
        elif r < p_had + p_s:
            c.add_gate("S", random.randrange(qubits))
        elif r < p_had + p_s + p_t:
            c.add_gate("T", random.randrange(qubits))
        else:
            tgt = random.randrange(qubits)
            while True:
                ctrl = random.randrange(qubits)
                if ctrl != tgt:
                    break
            c.add_gate("CNOT", tgt, ctrl)
    return c

# %%
# seed固定
seed = 1000
random.seed(seed)

# パラメータ設定
qubits_list = [4, 8, 12, 16]
p_t_lists = [i * 0.04 for i in range(0, 11)]
gate_num_lists = [100, 500, 1000, 2000, 5000, 10000, 50000]

# CSV書き込みの準備
output_file = "../kekka/1211basic_and_extract_50000.csv"
fieldnames = [
    "optimize_name","data_name","gates","depth","t","H","otherRZ","CNOT","CZ","time"
]
start_all = time.time()
with open(output_file, "w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()

    for qubit in qubits_list:
        for gate_num in gate_num_lists:
            for p_t in p_t_lists:
                try:
                    start = time.time()
                    # 回路作成
                    c = generate_H_S_CNOT_T_circuit(qubits = qubit,gates= gate_num,p_t = p_t,seed = seed)
                    c = zx.optimize.basic_optimization(c)
                    #グラフ変換
                    g = c.to_graph()

                    c  = zx.extract.streaming_extract(g)

                    c = zx.optimize.basic_optimization(c)

                    end = time.time()

                    #qiskit変換とカウント
                    circuit_qiskit = QuantumCircuit.from_qasm_str(c.to_basic_gates().to_qasm())
                    depth = circuit_qiskit.depth()
                    zx_dict = c.to_basic_gates().stats_dict()
                    qiskit_dict = circuit_qiskit.count_ops()

                    optimize_name = "basic"
                    dataname = "q" + str(qubit) + "_gates" + str(gate_num) + "_pt" +str(p_t)+ "_seeds" + str(seed)
                    gates_aft = zx_dict["gates"]


                    # 結果をCSVに書き込む
                    writer.writerow({
                        "optimize_name": optimize_name,
                        "data_name": dataname,
                        "gates": gates_aft,
                        "depth": depth,
                        "t": zx_dict["tcount"],
                        "H": qiskit_dict.get("h", 0),
                        "otherRZ": gates_aft - qiskit_dict.get("h", 0) - qiskit_dict.get("cx", 0) - qiskit_dict.get("cz", 0) - zx_dict["tcount"],
                        "CNOT": qiskit_dict.get("cx", 0),
                        "CZ": qiskit_dict.get("cz", 0),
                        "time": end - start
                    })

                    print(f"done. Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t},seed={seed},time={end-start}")

                except Exception as e:
                    print(f"Error for Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t}: {e}")

end_all = time.time()
print(f"Total time: {end_all - start_all}")
# Out:
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.2,seed=1000,time=0.15321898460388184
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.24,seed=1000,time=0.12015581130981445
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.28,seed=1000,time=0.11766529083251953
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.32,seed=1000,time=0.13862299919128418
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.36,seed=1000,time=0.09537053108215332
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.4,seed=1000,time=0.09966778755187988
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.0,seed=1000,time=0.43901777267456055
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.04,seed=1000,time=0.4407670497894287
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.08,seed=1000,time=0.4902057647705078
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.12,seed=1000,time=0.4385538101196289
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.16,seed=1000,time=0.47953367233276367
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.2,seed=1000,time=0.39136528968811035
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.24,seed=1000,time=0.38547682762145996
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.28,seed=1000,time=0.4056980609893799
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.32,seed=1000,time=0.3632798194885254
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.36,seed=1000,time=0.35802149772644043
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.4,seed=1000,time=0.34467434883117676
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.0,seed=1000,time=1.1400036811828613
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.04,seed=1000,time=1.0857255458831787
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.08,seed=1000,time=1.2181620597839355
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.12,seed=1000,time=1.1900579929351807
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.16,seed=1000,time=1.2902209758758545
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.2,seed=1000,time=1.0210444927215576
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.24,seed=1000,time=1.2019736766815186
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.28,seed=1000,time=1.229264259338379
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.32,seed=1000,time=1.0320937633514404
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.36,seed=1000,time=0.8995258808135986
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.4,seed=1000,time=0.8426008224487305
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.0,seed=1000,time=16.640934228897095
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.04,seed=1000,time=21.2487051486969
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.08,seed=1000,time=18.6688334941864
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.12,seed=1000,time=16.881990432739258
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.16,seed=1000,time=16.970514059066772
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.2,seed=1000,time=16.70729684829712
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.24,seed=1000,time=16.86404013633728
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.28,seed=1000,time=16.64190125465393
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.32,seed=1000,time=15.31880235671997
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.36,seed=1000,time=14.829464673995972
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.4,seed=1000,time=16.39087152481079
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.0,seed=1000,time=0.011466503143310547
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.04,seed=1000,time=0.008405685424804688
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.08,seed=1000,time=0.007319211959838867
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.12,seed=1000,time=0.007786989212036133
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.16,seed=1000,time=0.007694244384765625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.2,seed=1000,time=0.0072362422943115234
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.24,seed=1000,time=0.006988048553466797
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.28,seed=1000,time=0.007560253143310547
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.32,seed=1000,time=0.006901741027832031
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.36,seed=1000,time=0.0072176456451416016
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.4,seed=1000,time=0.007129192352294922
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.0,seed=1000,time=0.09807419776916504
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.04,seed=1000,time=0.04363822937011719
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0