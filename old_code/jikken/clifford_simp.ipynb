# %%
import pyzx as zx
import random
from qiskit import QuantumCircuit
from qiskit.circuit import QuantumCircuit, ParameterVector
import csv
import time

# %%
def generate_H_S_CNOT_T_circuit(qubits, gates, p_t=0, seed=1000):
    random.seed(seed)  
    p_s = 0.333 * (1.0 - p_t)  
    p_had = 0.333 * (1.0 - p_t)  
    p_cnot = 0.333 * (1.0 - p_t)  

    c = zx.Circuit(qubits) 
    for _ in range(gates):
        r = random.random() 
        if r < p_had:
            c.add_gate("HAD", random.randrange(qubits))
        elif r < p_had + p_s:
            c.add_gate("S", random.randrange(qubits))
        elif r < p_had + p_s + p_t:
            c.add_gate("T", random.randrange(qubits))
        else:
            tgt = random.randrange(qubits)
            while True:
                ctrl = random.randrange(qubits)
                if ctrl != tgt:
                    break
            c.add_gate("CNOT", tgt, ctrl)
    return c

# %%
# seed固定
seed = 1001
random.seed(seed)

# パラメータ設定
qubits_list = [4, 8, 12, 16]
p_t_lists = [i * 0.04 for i in range(0, 11)]
gate_num_lists = [100, 500, 1000, 2000, 5000, 10000, 50000]

# CSV書き込みの準備
output_file = "../kekka1215/1215clifford_simp_50000_atonibasic_seed1001.csv"
fieldnames = [
    "optimize_name","data_name","gates","depth","t","H","otherRZ","CNOT","CZ","time"
]
start_all = time.time()
with open(output_file, "w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()

    for qubit in qubits_list:
        for gate_num in gate_num_lists:
            for p_t in p_t_lists:
                try:
                    start = time.time()
                    # 回路作成
                    c = generate_H_S_CNOT_T_circuit(qubits = qubit,gates= gate_num,p_t = p_t,seed = seed)
                    c = zx.optimize.basic_optimization(c)
                    g = c.to_graph()
                    zx.simplify.clifford_simp(g)


                    #抽出
                    c = zx.extract.streaming_extract(g)
                    c = zx.optimize.basic_optimization(c)

                    end = time.time()

                    #qiskit変換とカウント
                    circuit_qiskit = QuantumCircuit.from_qasm_str(c.to_basic_gates().to_qasm())
                    depth = circuit_qiskit.depth()
                    zx_dict = c.to_basic_gates().stats_dict()
                    qiskit_dict = circuit_qiskit.count_ops()

                    optimize_name = "clifford_simp"
                    dataname = "q" + str(qubit) + "_gates" + str(gate_num) + "_pt" +str(p_t)+ "_seeds" + str(seed)
                    gates_aft = zx_dict["gates"]


                    # 結果をCSVに書き込む
                    writer.writerow({
                        "optimize_name": optimize_name,
                        "data_name": dataname,
                        "gates": gates_aft,
                        "depth": depth,
                        "t": zx_dict["tcount"],
                        "H": qiskit_dict.get("h", 0),
                        "otherRZ": gates_aft - qiskit_dict.get("h", 0) - qiskit_dict.get("cx", 0) - qiskit_dict.get("cz", 0) - zx_dict["tcount"],
                        "CNOT": qiskit_dict.get("cx", 0),
                        "CZ": qiskit_dict.get("cz", 0),
                        "time": end - start
                    })

                    print(f"done. Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t},seed={seed},time={end-start}")

                except Exception as e:
                    print(f"Error for Qubits={qubit}, Gate_Num={gate_num}, P_T={p_t}: {e}")

end_all = time.time()
print(f"Total time: {end_all - start_all}")
# Out:
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.0,seed=1001,time=0.015528678894042969
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.04,seed=1001,time=0.007565975189208984
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.08,seed=1001,time=0.006376743316650391
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.12,seed=1001,time=0.006419658660888672
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.16,seed=1001,time=0.006512641906738281
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.2,seed=1001,time=0.006587505340576172
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.24,seed=1001,time=0.006198883056640625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.28,seed=1001,time=0.007482767105102539
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.32,seed=1001,time=0.007854461669921875
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.36,seed=1001,time=0.007260322570800781
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=100, P_T=0.4,seed=1001,time=0.007197380065917969
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.0,seed=1001,time=0.022093534469604492
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.04,seed=1001,time=0.02662062644958496
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.08,seed=1001,time=0.02766728401184082
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.12,seed=1001,time=0.030452489852905273
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.16,seed=1001,time=0.0335843563079834
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.2,seed=1001,time=0.03361392021179199
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.24,seed=1001,time=0.034539222717285156
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.28,seed=1001,time=0.031012773513793945
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.32,seed=1001,time=0.027640819549560547
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.36,seed=1001,time=0.03276419639587402
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=500, P_T=0.4,seed=1001,time=0.03196883201599121
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.0,seed=1001,time=0.05394458770751953
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.04,seed=1001,time=0.05883073806762695
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.08,seed=1001,time=0.06927132606506348
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.12,seed=1001,time=0.06731343269348145
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.16,seed=1001,time=0.07231831550598145
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.2,seed=1001,time=0.06813859939575195
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.24,seed=1001,time=0.06898236274719238
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.28,seed=1001,time=0.07117795944213867
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.32,seed=1001,time=0.061078548431396484
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.36,seed=1001,time=0.062218666076660156
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=1000, P_T=0.4,seed=1001,time=0.06806015968322754
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.0,seed=1001,time=0.17507147789001465
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.04,seed=1001,time=0.14046955108642578
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.08,seed=1001,time=0.16304922103881836
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.12,seed=1001,time=0.18262195587158203
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.16,seed=1001,time=0.15091347694396973
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.2,seed=1001,time=0.1894547939300537
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.24,seed=1001,time=0.15529251098632812
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.28,seed=1001,time=0.1639564037322998
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.32,seed=1001,time=0.19785547256469727
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.36,seed=1001,time=0.1713545322418213
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=2000, P_T=0.4,seed=1001,time=0.15718650817871094
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.0,seed=1001,time=0.46634387969970703
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.04,seed=1001,time=0.46336841583251953
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.08,seed=1001,time=0.5771329402923584
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.12,seed=1001,time=0.5985984802246094
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.16,seed=1001,time=0.5955541133880615
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.2,seed=1001,time=0.6285607814788818
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.24,seed=1001,time=0.6275818347930908
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.28,seed=1001,time=0.5563440322875977
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.32,seed=1001,time=0.667682409286499
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.36,seed=1001,time=0.70157790184021
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=5000, P_T=0.4,seed=1001,time=0.6471490859985352
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.0,seed=1001,time=1.2500412464141846
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.04,seed=1001,time=1.4079458713531494
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.08,seed=1001,time=1.7200696468353271
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.12,seed=1001,time=1.9007530212402344
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.16,seed=1001,time=1.9457335472106934
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.2,seed=1001,time=1.7280397415161133
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.24,seed=1001,time=1.7608351707458496
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.28,seed=1001,time=1.9529588222503662
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.32,seed=1001,time=1.9118189811706543
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.36,seed=1001,time=1.9391286373138428
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=10000, P_T=0.4,seed=1001,time=1.9131762981414795
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.0,seed=1001,time=25.11144208908081
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.04,seed=1001,time=28.733757495880127
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.08,seed=1001,time=29.444926738739014
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.12,seed=1001,time=32.3878812789917
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.16,seed=1001,time=33.147512674331665
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.2,seed=1001,time=36.458574295043945
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.24,seed=1001,time=36.00300097465515
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.28,seed=1001,time=33.54936099052429
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.32,seed=1001,time=34.39085388183594
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.36,seed=1001,time=36.563409090042114
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=4, Gate_Num=50000, P_T=0.4,seed=1001,time=37.346309185028076
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.0,seed=1001,time=0.0121002197265625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.04,seed=1001,time=0.009535551071166992
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.08,seed=1001,time=0.01163029670715332
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.12,seed=1001,time=0.009721517562866211
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.16,seed=1001,time=0.012788772583007812
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.2,seed=1001,time=0.011350870132446289
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.24,seed=1001,time=0.010729551315307617
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.28,seed=1001,time=0.009048938751220703
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.32,seed=1001,time=0.012835264205932617
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.36,seed=1001,time=0.009832382202148438
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=100, P_T=0.4,seed=1001,time=0.009224891662597656
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.0,seed=1001,time=0.0449373722076416
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.04,seed=1001,time=0.049021005630493164
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.08,seed=1001,time=0.0541079044342041
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.12,seed=1001,time=0.055303335189819336
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.16,seed=1001,time=0.056185245513916016
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.2,seed=1001,time=0.06184530258178711
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.24,seed=1001,time=0.05639815330505371
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.28,seed=1001,time=0.055570125579833984
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.32,seed=1001,time=0.07484316825866699
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.36,seed=1001,time=0.06115365028381348
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=500, P_T=0.4,seed=1001,time=0.05360722541809082
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.0,seed=1001,time=0.08383941650390625
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.04,seed=1001,time=0.10822820663452148
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.08,seed=1001,time=0.14604687690734863
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.12,seed=1001,time=0.1226189136505127
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.16,seed=1001,time=0.12439298629760742
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.2,seed=1001,time=0.10659217834472656
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.24,seed=1001,time=0.10650849342346191
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.28,seed=1001,time=0.10292935371398926
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.32,seed=1001,time=0.10260677337646484
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.36,seed=1001,time=0.09676408767700195
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=1000, P_T=0.4,seed=1001,time=0.09140729904174805
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.0,seed=1001,time=0.20477676391601562
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.04,seed=1001,time=0.18905091285705566
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.08,seed=1001,time=0.25855231285095215
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.12,seed=1001,time=0.24338293075561523
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.16,seed=1001,time=0.24130582809448242
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.2,seed=1001,time=0.20920348167419434
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.24,seed=1001,time=0.2538881301879883
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.28,seed=1001,time=0.22983789443969727
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.32,seed=1001,time=0.2577857971191406
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.36,seed=1001,time=0.22540736198425293
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=2000, P_T=0.4,seed=1001,time=0.22022628784179688
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.0,seed=1001,time=0.7252030372619629
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.04,seed=1001,time=0.7897913455963135
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.08,seed=1001,time=0.8204555511474609
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.12,seed=1001,time=0.7849373817443848
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.16,seed=1001,time=0.7229170799255371
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.2,seed=1001,time=0.661933183670044
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.24,seed=1001,time=0.7832005023956299
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.28,seed=1001,time=0.6341598033905029
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.32,seed=1001,time=0.6711781024932861
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.36,seed=1001,time=0.6242187023162842
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=5000, P_T=0.4,seed=1001,time=0.6313729286193848
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.0,seed=1001,time=1.629103183746338
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.04,seed=1001,time=1.7883896827697754
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.08,seed=1001,time=1.8878042697906494
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.12,seed=1001,time=1.8474881649017334
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.16,seed=1001,time=2.0301241874694824
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.2,seed=1001,time=1.9783604145050049
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.24,seed=1001,time=1.8367950916290283
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.28,seed=1001,time=1.8938167095184326
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.32,seed=1001,time=1.921112298965454
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.36,seed=1001,time=1.7044215202331543
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=10000, P_T=0.4,seed=1001,time=1.5527381896972656
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.0,seed=1001,time=24.880098819732666
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.04,seed=1001,time=24.29172134399414
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.08,seed=1001,time=23.31085968017578
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.12,seed=1001,time=27.759827852249146
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.16,seed=1001,time=26.96777629852295
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.2,seed=1001,time=30.291611671447754
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.24,seed=1001,time=30.142032623291016
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.28,seed=1001,time=29.244757890701294
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.32,seed=1001,time=28.52825164794922
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.36,seed=1001,time=31.248926162719727
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=8, Gate_Num=50000, P_T=0.4,seed=1001,time=24.968053579330444
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.0,seed=1001,time=0.01500701904296875
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.04,seed=1001,time=0.013931035995483398
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.08,seed=1001,time=0.01224207878112793
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.12,seed=1001,time=0.014995098114013672
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.16,seed=1001,time=0.010423660278320312
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.2,seed=1001,time=0.012275934219360352
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.24,seed=1001,time=0.012073516845703125
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.28,seed=1001,time=0.01112222671508789
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.32,seed=1001,time=0.01170969009399414
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.36,seed=1001,time=0.008978128433227539
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=100, P_T=0.4,seed=1001,time=0.010183095932006836
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.0,seed=1001,time=0.053453683853149414
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.04,seed=1001,time=0.07243108749389648
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.08,seed=1001,time=0.0859215259552002
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.12,seed=1001,time=0.08051824569702148
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.16,seed=1001,time=0.07361841201782227
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.2,seed=1001,time=0.07846713066101074
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.24,seed=1001,time=0.07340097427368164
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.28,seed=1001,time=0.06517386436462402
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.32,seed=1001,time=0.1020960807800293
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.36,seed=1001,time=0.05801725387573242
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=500, P_T=0.4,seed=1001,time=0.06070375442504883
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.0,seed=1001,time=0.10733890533447266
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.04,seed=1001,time=0.15637707710266113
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.08,seed=1001,time=0.17835450172424316
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.12,seed=1001,time=0.17339777946472168
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.16,seed=1001,time=0.1941678524017334
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.2,seed=1001,time=0.1613938808441162
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.24,seed=1001,time=0.14913725852966309
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.28,seed=1001,time=0.13557815551757812
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.32,seed=1001,time=0.16147661209106445
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.36,seed=1001,time=0.11278367042541504
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=1000, P_T=0.4,seed=1001,time=0.1065058708190918
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.0,seed=1001,time=0.24231338500976562
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.04,seed=1001,time=0.4358072280883789
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.08,seed=1001,time=0.3810112476348877
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.12,seed=1001,time=0.4908485412597656
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.16,seed=1001,time=0.39036107063293457
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.2,seed=1001,time=0.34206533432006836
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.24,seed=1001,time=0.296983003616333
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.28,seed=1001,time=0.3289215564727783
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.32,seed=1001,time=0.25261831283569336
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.36,seed=1001,time=0.282665491104126
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=2000, P_T=0.4,seed=1001,time=0.20434331893920898
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.0,seed=1001,time=0.9788608551025391
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.04,seed=1001,time=1.694138765335083
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.08,seed=1001,time=1.2987074851989746
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.12,seed=1001,time=1.1117711067199707
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.16,seed=1001,time=1.183581829071045
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.2,seed=1001,time=1.1148695945739746
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.24,seed=1001,time=0.9272704124450684
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.28,seed=1001,time=0.9323756694793701
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.32,seed=1001,time=0.8634061813354492
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.36,seed=1001,time=0.8677682876586914
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=5000, P_T=0.4,seed=1001,time=0.717689037322998
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.0,seed=1001,time=2.5038180351257324
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.04,seed=1001,time=5.056290626525879
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.08,seed=1001,time=3.496821641921997
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.12,seed=1001,time=2.5706565380096436
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.16,seed=1001,time=2.5930778980255127
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.2,seed=1001,time=2.397160768508911
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.24,seed=1001,time=2.331900119781494
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.28,seed=1001,time=2.50724196434021
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.32,seed=1001,time=2.081709384918213
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.36,seed=1001,time=2.121347188949585
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=10000, P_T=0.4,seed=1001,time=1.9045109748840332
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.0,seed=1001,time=30.776583909988403
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.04,seed=1001,time=59.085283279418945
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.08,seed=1001,time=34.5009663105011
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.12,seed=1001,time=34.385818004608154
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.16,seed=1001,time=28.35821557044983
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.2,seed=1001,time=29.380407333374023
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.24,seed=1001,time=31.78451156616211
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.28,seed=1001,time=26.90694236755371
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.32,seed=1001,time=28.896648645401
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.36,seed=1001,time=23.28696846961975
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=12, Gate_Num=50000, P_T=0.4,seed=1001,time=20.242858409881592
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.0,seed=1001,time=0.020847558975219727
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.04,seed=1001,time=0.016733169555664062
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.08,seed=1001,time=0.016354084014892578
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.12,seed=1001,time=0.014518499374389648
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.16,seed=1001,time=0.014499187469482422
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.2,seed=1001,time=0.013078927993774414
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.24,seed=1001,time=0.015208959579467773
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.28,seed=1001,time=0.01375579833984375
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.32,seed=1001,time=0.01387166976928711
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.36,seed=1001,time=0.010313987731933594
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=100, P_T=0.4,seed=1001,time=0.00844264030456543
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.0,seed=1001,time=0.11504936218261719
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.04,seed=1001,time=0.09869694709777832
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.08,seed=1001,time=0.10887312889099121
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.12,seed=1001,time=0.13027477264404297
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.16,seed=1001,time=0.10836482048034668
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.2,seed=1001,time=0.09271645545959473
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.24,seed=1001,time=0.08729934692382812
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.28,seed=1001,time=0.08469080924987793
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.32,seed=1001,time=0.07126712799072266
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.36,seed=1001,time=0.0738837718963623
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=500, P_T=0.4,seed=1001,time=0.0652925968170166
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.0,seed=1001,time=0.20781707763671875
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.04,seed=1001,time=0.37149977684020996
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.08,seed=1001,time=0.3307204246520996
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.12,seed=1001,time=0.27315425872802734
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.16,seed=1001,time=0.2822422981262207
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.2,seed=1001,time=0.2228221893310547
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.24,seed=1001,time=0.18627643585205078
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.28,seed=1001,time=0.16759991645812988
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.32,seed=1001,time=0.17356419563293457
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.36,seed=1001,time=0.1784358024597168
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=1000, P_T=0.4,seed=1001,time=0.14182400703430176
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.0,seed=1001,time=0.4489264488220215
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.04,seed=1001,time=1.3601081371307373
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.08,seed=1001,time=1.3671863079071045
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.12,seed=1001,time=0.92659592628479
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.16,seed=1001,time=0.7472474575042725
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.2,seed=1001,time=0.5341324806213379
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.24,seed=1001,time=0.4313499927520752
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.28,seed=1001,time=0.4622385501861572
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.32,seed=1001,time=0.34830260276794434
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.36,seed=1001,time=0.3581571578979492
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=2000, P_T=0.4,seed=1001,time=0.3354015350341797
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.0,seed=1001,time=1.425133466720581
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.04,seed=1001,time=7.250530481338501
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.08,seed=1001,time=6.003931760787964
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.12,seed=1001,time=2.4130239486694336
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.16,seed=1001,time=2.079873561859131
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.2,seed=1001,time=1.5841701030731201
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.24,seed=1001,time=1.2798504829406738
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.28,seed=1001,time=1.2733392715454102
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.32,seed=1001,time=1.18630051612854
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.36,seed=1001,time=1.0875535011291504
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=5000, P_T=0.4,seed=1001,time=1.0233139991760254
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.0,seed=1001,time=3.893712043762207
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.04,seed=1001,time=26.351191759109497
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.08,seed=1001,time=10.97325873374939
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.12,seed=1001,time=5.592693567276001
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.16,seed=1001,time=4.137641429901123
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.2,seed=1001,time=3.4766697883605957
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.24,seed=1001,time=3.6330602169036865
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.28,seed=1001,time=2.6622397899627686
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.32,seed=1001,time=2.5859508514404297
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.36,seed=1001,time=2.5076587200164795
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=10000, P_T=0.4,seed=1001,time=2.3284735679626465
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.0,seed=1001,time=63.64531326293945
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.04,seed=1001,time=372.680104970932
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.08,seed=1001,time=91.2975537776947
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.12,seed=1001,time=55.07828617095947
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.16,seed=1001,time=46.07392501831055
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.2,seed=1001,time=38.55702471733093
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.24,seed=1001,time=34.11636567115784
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.28,seed=1001,time=35.26911759376526
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.32,seed=1001,time=25.7999165058136
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.36,seed=1001,time=25.60089635848999
# This function is deprecated. Call extract_circuit() instead.
# done. Qubits=16, Gate_Num=50000, P_T=0.4,seed=1001,time=26.34736919403076
# Total time: 2050.207062482834
